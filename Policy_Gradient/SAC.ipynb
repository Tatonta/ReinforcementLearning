# %%
import copy

import torch
import gym
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter
from torch.distributions import Normal
import itertools

# %%
class SACBuffer:
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.counter = 0
        self.states_memory = np.zeros((self.mem_size, *input_shape))
        self.actions_memory = np.zeros((self.mem_size, n_actions))
        self.new_states_memory = np.zeros((self.mem_size, *input_shape))
        self.rewards_memory = np.zeros(self.mem_size)
        self.dones = np.zeros(self.mem_size)

    def store_transition(self, state, action, reward, new_state, done):
        self.index = self.counter % self.mem_size
        self.states_memory[index] = state
        self.actions_memory[index] = action
        self.rewards_memory[index] = reward
        self.new_states_memory[index] = new_state
        self.dones[index] = done
        self.counter += 1

    def sample_buffer(self, batch_size):
        max_mem = self.counter
        if self.counter > self.mem_size:
            max_mem = self.mem_size
        batch = np.random.choice(max_mem, batch_size)

        states = self.states_memory[batch]
        rewards = self.rewards_memory[batch]
        new_states = self.new_states_memory[batch]
        actions = self.actions_memory[batch]
        dones = self.dones[batch]

        return states, rewards, actions, new_states, dones

class ActionEstimator(nn.Module):
    def __init__(self, input_dims, actions, max_action, hidden_sizes):
        super(ActionEstimator, self).__init__()
        self.max_action = max_action
        self.hidden_sizes = hidden_sizes
        self.reparam_noise = 1e-6
        self.LOG_STD_MAX = 2
        self.LOG_STD_MIN = -20
        self.SeqLayer = nn.Sequential(
            nn.Linear(*input_dims, hidden_sizes[0]),
            nn.ReLU(),
            nn.Linear(hidden_sizes[0], hidden_sizes[1]),
            nn.ReLU(),
        )
        self.mu = nn.Linear(hidden_sizes[1], actions)
        self.sigma = nn.Linear(hidden_sizes[1], actions)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def forward(self, state):
        out = self.SeqLayer(state)
        mu = self.mu(out)
        log_std = self.sigma(out)
        log_std = torch.clamp(log_std, self.LOG_STD_MIN, self.LOG_STD_MAX)
        return mu, log_std

    def act(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0).to(self.device)
        mu, log_std = self.forward(state)
        sigma = torch.exp(log_std)
        gaussian_dist = Normal(mu, sigma)
        actions = gaussian_dist.rsample()
        actions = torch.tanh(actions)
        return actions.cpu().detach().numpy()[0]*self.max_action

    def evaluate(self, state):
        mu, log_std = self.forward(state)
        sigma = torch.exp(log_std)
        action_dist = Normal(mu, sigma)
        action = action_dist.rsample()

        log_prob = action_dist.log_prob(action)-torch.log(1-action.pow(2)+self.reparam_noise)
        log_prob = log_prob.sum(dim=-1)
        # log_prob = action_dist.log_prob(action).sum(axis=-1)
        # log_prob -= (2*(np.log(2) - action - F.softplus(-2*action))).sum(axis=1)

        return torch.tanh(action)*self.max_action, log_prob

class Q_Net(nn.Module):
    def __init__(self, input_dims, actions, hidden_sizes, learning_rate = 1e-3):
        super(Q_Net, self).__init__()
        self.hidden_sizes = hidden_sizes
        self.SeqLayer = nn.Sequential(
            nn.Linear(input_dims[0]+actions, self.hidden_sizes[0]),
            nn.ReLU(),
            nn.Linear(self.hidden_sizes[0], self.hidden_sizes[1]),
            nn.ReLU(),
            nn.Linear(self.hidden_sizes[1], 1)
        )

    def forward(self, state, actions):
        out = self.SeqLayer(torch.cat([state, actions], dim = -1))
        return out


class Agent:
    def __init__(self,  max_action, n_actions, input_dims, hidden_sizes = [256, 256], gamma=0.95, batch_size=256, learning_rate = 1e-3):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.gamma = gamma
        self.max_action = max_action
        self.batch_size = batch_size
        self.polyak = 0.995
        self.ALPHA_INITIAL = 1
        self.tau = 0.01
        self.actor = ActionEstimator(input_dims, n_actions, max_action, hidden_sizes).to(self.device)
        self.Q1 = Q_Net(input_dims, n_actions, hidden_sizes).to(self.device)
        self.Q2 = Q_Net(input_dims, n_actions, hidden_sizes).to(self.device)
        self.Q1_targ = copy.deepcopy(self.Q1)
        self.Q2_targ = copy.deepcopy(self.Q2)
        self.target_entropy = 0.98 * -np.log(1 / n_actions)
        self.log_alpha = torch.tensor(np.log(self.ALPHA_INITIAL), requires_grad=True)
        self.alpha = self.log_alpha
        self.alpha_optimizer = torch.optim.Adam([self.log_alpha], lr=1e-4)

        self.buffer = SACBuffer(50000, input_shape = input_dims, n_actions = n_actions)
        self.MSE_Criterion = nn.MSELoss()

        self.q_params = itertools.chain(self.Q1.parameters(), self.Q2.parameters())
        self.q_targ_params = itertools.chain(self.Q1_targ.parameters(), self.Q2_targ.parameters())
        self.q_optim = torch.optim.Adam(self.q_params, lr=0.00003)
        self.actor_optim = torch.optim.Adam(self.actor.parameters(), lr=0.00003)
        for p in self.q_targ_params:
            p.requires_grad = False

    def choose_action(self, state):
        action = self.actor.act(state)
        return action

    def update_network_parameters(self):
        for target_param, param in zip(self.Q1_targ.parameters(), self.Q1.parameters()):
            target_param.data.copy_(self.tau*param.data + (1-self.tau)*target_param.data)

        for target_param, param in zip(self.Q2_targ.parameters(), self.Q2.parameters()):
            target_param.data.copy_(self.tau*param.data + (1-self.tau)*target_param.data)

    def remember(self, s, a, r, ns, done):
        self.buffer.store_transition(s,a,r,ns,done)

    def update(self):
        if self.buffer.counter < self.batch_size:
            return
        states, rewards, actions, new_states, dones = self.buffer.sample_buffer(self.batch_size)

        states_t = torch.from_numpy(states).float().to(self.device)
        rewards_t = torch.from_numpy(rewards).float().to(self.device)
        actions_t = torch.from_numpy(actions).float().to(self.device)
        new_states_t = torch.from_numpy(new_states).float().to(self.device)
        dones_t = torch.from_numpy(dones).to(self.device)

        # LOSS FOR Q FUNCTION
        self.q_optim.zero_grad()

        q1_value = self.Q1(states_t, actions_t)
        q2_value = self.Q2(states_t, actions_t)

        with torch.no_grad():
            actions2, log_probs = self.actor.evaluate(new_states_t)
            q1_p_targ = self.Q1_targ(new_states_t, actions2)
            q2_p_targ = self.Q2_targ(new_states_t, actions2)
            q_min = torch.min(q1_p_targ, q2_p_targ)
            backup = rewards_t+self.gamma*(1-dones_t)*(q_min-self.alpha*log_probs)

        loss_q1 = ((q1_value-backup)**2).mean()
        loss_q2 = ((q2_value-backup)**2).mean()
        loss_qf = loss_q1 + loss_q2
        loss_qf.backward()
        self.q_optim.step()

        # Freeze Q-networks so you don't waste computational effort
        # computing gradients for them during the policy learning step.
        for p in self.q_params:
            p.requires_grad = False

        # Updating Policy
        self.actor_optim.zero_grad()
        new_act, new_log_probs = self.actor(states_t)
        q1_p = self.Q1(states_t, new_act)
        q2_p = self.Q2(states_t, new_act)
        q_p_min = torch.min(q1_p, q2_p)
        policy_loss = (self.alpha*new_log_probs-q_p_min).mean()
        policy_loss.backward()
        self.actor_optim.step()

        # Unfreeze Q-networks so you can optimize it at next DDPG step.
        for p in self.q_params:
            p.requires_grad = True

        alpha_loss = -(self.log_alpha * (log_probs + self.target_entropy).detach()).mean()
        alpha_loss.backward()
        self.alpha_optimizer.step()
        self.alpha = self.log_alpha.exp()
        # Finally, update target networks by polyak averaging.
        self.update_network_parameters()


env = gym.make("LunarLanderContinuous-v2")
writer = SummaryWriter()
max_action = env.action_space.high[0]
n_actions = env.action_space.shape[0]
obs_dim = env.observation_space.shape
n_games = 4000
agent = Agent(max_action, n_actions, obs_dim)
exploration_end = 10000
start_updates = 1000
update_steps = 50
index = 0
eps_rewards = []
updating = 0
for i in range(n_games):
    done = False
    score = 0
    obs = env.reset()
    while not done:
        action = agent.choose_action(obs)
        index+=1
        new_state, reward, done, info = env.step(action)
        agent.remember(obs, action, reward, new_state, int(done))
        if index > start_updates and index % update_steps == 0:
            agent.update()
        score += reward
        obs = new_state
    eps_rewards.append(score)
    avg_score = np.mean(eps_rewards[-100:])
    writer.add_scalar("Episode total reward", eps_rewards[i], i)

    print('episode ', i, " score %.2f " %score,
          "100 game average %.2f" % avg_score)
# Out:
# episode  0  score -118.20  100 game average -118.20
# episode  1  score -423.15  100 game average -270.67
# episode  2  score -70.63  100 game average -203.99
# episode  3  score -62.91  100 game average -168.72
# episode  4  score -96.43  100 game average -154.26
# episode  5  score -446.72  100 game average -203.01
# episode  6  score -285.32  100 game average -214.77
# episode  7  score -183.45  100 game average -210.85
# episode  8  score -407.55  100 game average -232.71
# episode  9  score -115.97  100 game average -221.03
# episode  10  score -273.12  100 game average -225.77
# episode  11  score -406.18  100 game average -240.80
# episode  12  score -219.27  100 game average -239.15
# episode  13  score -172.60  100 game average -234.39
# episode  14  score -55.69  100 game average -222.48
# episode  15  score -66.42  100 game average -212.73
# episode  16  score -91.63  100 game average -205.60
# episode  17  score -309.32  100 game average -211.37
# episode  18  score -68.19  100 game average -203.83
# episode  19  score -440.55  100 game average -215.67
# episode  20  score -76.18  100 game average -209.02
# episode  21  score -185.89  100 game average -207.97
# episode  22  score -354.51  100 game average -214.34
# episode  23  score -53.60  100 game average -207.65
# episode  24  score -236.58  100 game average -208.80
# episode  25  score -88.31  100 game average -204.17
# episode  26  score -81.23  100 game average -199.62
# episode  27  score -70.55  100 game average -195.01
# episode  28  score -33.07  100 game average -189.42
# episode  29  score -91.06  100 game average -186.14
# episode  30  score -65.53  100 game average -182.25
# episode  31  score -161.85  100 game average -181.61
# episode  32  score -228.65  100 game average -183.04
# episode  33  score -444.76  100 game average -190.74
# episode  34  score -425.39  100 game average -197.44
# episode  35  score -494.30  100 game average -205.69
# episode  36  score -409.60  100 game average -211.20
# episode  37  score -290.84  100 game average -213.30
# episode  38  score -461.54  100 game average -219.66
# episode  39  score -183.68  100 game average -218.76
# episode  40  score -162.17  100 game average -217.38
# episode  41  score -271.77  100 game average -218.68
# episode  42  score -332.75  100 game average -221.33
# episode  43  score -89.07  100 game average -218.32
# episode  44  score -261.28  100 game average -219.28
# episode  45  score -179.87  100 game average -218.42
# episode  46  score -120.57  100 game average -216.34
# episode  47  score -206.86  100 game average -216.14
# episode  48  score -142.70  100 game average -214.64
# episode  49  score -78.41  100 game average -211.92
# episode  50  score -446.25  100 game average -216.51
# episode  51  score -468.35  100 game average -221.36
# episode  52  score -298.01  100 game average -222.80
# episode  53  score -120.13  100 game average -220.90
# episode  54  score -73.68  100 game average -218.22
# episode  55  score -436.22  100 game average -222.12
# episode  56  score -87.56  100 game average -219.76
# episode  57  score -375.18  100 game average -222.44
# episode  58  score -163.96  100 game average -221.44
# episode  59  score -90.20  100 game average -219.26
# episode  60  score -18.74  100 game average -215.97
# episode  61  score -76.27  100 game average -213.72
# episode  62  score -280.58  100 game average -214.78
# episode  63  score -278.36  100 game average -215.77
# episode  64  score -165.50  100 game average -215.00
# episode  65  score -152.84  100 game average -214.06
# episode  66  score -297.77  100 game average -215.31
# episode  67  score -48.94  100 game average -212.86
# episode  68  score -488.26  100 game average -216.85
# episode  69  score -246.77  100 game average -217.28
# episode  70  score -163.97  100 game average -216.53
# episode  71  score -263.71  100 game average -217.18
# episode  72  score -233.41  100 game average -217.40
# episode  73  score -277.14  100 game average -218.21
# episode  74  score -104.31  100 game average -216.69
# episode  75  score -232.78  100 game average -216.91
# episode  76  score -344.36  100 game average -218.56
# episode  77  score -443.83  100 game average -221.45
# episode  78  score -90.42  100 game average -219.79
# episode  79  score -378.79  100 game average -221.78
# episode  80  score -104.26  100 game average -220.33
# episode  81  score -321.86  100 game average -221.56
# episode  82  score -79.89  100 game average -219.86
# episode  83  score -61.95  100 game average -217.98
# episode  84  score -267.01  100 game average -218.55
# episode  85  score -384.95  100 game average -220.49
# episode  86  score -477.14  100 game average -223.44
# episode  87  score -211.66  100 game average -223.31
# episode  88  score -161.52  100 game average -222.61
# episode  89  score -416.97  100 game average -224.77
# episode  90  score -288.46  100 game average -225.47
# episode  91  score -432.74  100 game average -227.72
# episode  92  score -22.61  100 game average -225.52
# episode  93  score -365.50  100 game average -227.01
# episode  94  score -141.27  100 game average -226.10
# episode  95  score -117.28  100 game average -224.97
# episode  96  score -240.50  100 game average -225.13
# episode  97  score -120.37  100 game average -224.06
# episode  98  score -354.22  100 game average -225.38
# episode  99  score -117.72  100 game average -224.30
# episode  100  score -290.26  100 game average -226.02
# episode  101  score -419.89  100 game average -225.99
# episode  102  score -295.77  100 game average -228.24
# episode  103  score -249.62  100 game average -230.11
# episode  104  score -89.71  100 game average -230.04
# episode  105  score -328.76  100 game average -228.86
# episode  106  score -96.30  100 game average -226.97
# episode  107  score -479.01  100 game average -229.93
# episode  108  score -350.83  100 game average -229.36
# episode  109  score -202.61  100 game average -230.22
# episode  110  score -349.58  100 game average -230.99
# episode  111  score -228.18  100 game average -229.21
# episode  112  score -315.48  100 game average -230.17
# episode  113  score -114.98  100 game average -229.60
# episode  114  score -297.93  100 game average -232.02
# episode  115  score -104.72  100 game average -232.40
# episode  116  score -62.55  100 game average -232.11
# episode  117  score -144.13  100 game average -230.46
# episode  118  score -62.87  100 game average -230.40
# episode  119  score -360.35  100 game average -229.60
# episode  120  score -40.66  100 game average -229.25
# episode  121  score -124.67  100 game average -228.64
# episode  122  score -160.79  100 game average -226.70
# episode  123  score -85.00  100 game average -227.01
# episode  124  score -259.71  100 game average -227.24
# episode  125  score -83.19  100 game average -227.19
# episode  126  score -201.90  100 game average -228.40
# episode  127  score -147.54  100 game average -229.17
# episode  128  score -106.81  100 game average -229.91
# episode  129  score -295.93  100 game average -231.95
# episode  130  score -188.10  100 game average -233.18
# episode  131  score -300.49  100 game average -234.57
# episode  132  score -169.21  100 game average -233.97
# episode  133  score -268.60  100 game average -232.21
# episode  134  score -239.92  100 game average -230.36
# episode  135  score -74.03  100 game average -226.15
# episode  136  score -170.78  100 game average -223.77
# episode  137  score -136.16  100 game average -222.22
# episode  138  score -289.82  100 game average -220.50
# episode  139  score -222.97  100 game average -220.89
# episode  140  score -79.00  100 game average -220.06
# episode  141  score -198.31  100 game average -219.33
# episode  142  score -105.76  100 game average -217.06
# episode  143  score -113.08  100 game average -217.30
# episode  144  score 24.05  100 game average -214.44
# episode  145  score -117.93  100 game average -213.83
# episode  146  score -180.75  100 game average -214.43
# episode  147  score -78.56  100 game average -213.14
# episode  148  score -255.73  100 game average -214.27
# episode  149  score -151.80  100 game average -215.01
# episode  150  score -152.64  100 game average -212.07
# episode  151  score -61.14  100 game average -208.00
# episode  152  score -241.23  100 game average -207.43
# episode  153  score -287.40  100 game average -209.10
# episode  154  score -355.92  100 game average -211.93
# episode  155  score -107.77  100 game average -208.64
# episode  156  score -69.80  100 game average -208.47
# episode  157  score -378.19  100 game average -208.50
# episode  158  score -85.37  100 game average -207.71
# episode  159  score -168.46  100 game average -208.49
# episode  160  score -93.53  100 game average -209.24
# episode  161  score -132.45  100 game average -209.80
# episode  162  score -174.39  100 game average -208.74
# episode  163  score -354.43  100 game average -209.50
# episode  164  score -64.22  100 game average -208.49
# episode  165  score -110.74  100 game average -208.07
# episode  166  score -80.94  100 game average -205.90
# episode  167  score -90.50  100 game average -206.31
# episode  168  score -197.87  100 game average -203.41
# episode  169  score -108.94  100 game average -202.03
# episode  170  score -199.47  100 game average -202.39
# episode  171  score -167.09  100 game average -201.42
# episode  172  score -156.06  100 game average -200.65
# episode  173  score -121.28  100 game average -199.09
# episode  174  score -157.24  100 game average -199.62
# episode  175  score -148.01  100 game average -198.77
# episode  176  score -80.34  100 game average -196.13
# episode  177  score -216.91  100 game average -193.86
# episode  178  score -178.79  100 game average -194.74
# episode  179  score -147.63  100 game average -192.43
# episode  180  score -144.79  100 game average -192.84
# episode  181  score -176.77  100 game average -191.39
# episode  182  score -125.50  100 game average -191.84
# episode  183  score -167.46  100 game average -192.90
# episode  184  score -79.51  100 game average -191.02
# episode  185  score -129.62  100 game average -188.47
# episode  186  score -124.36  100 game average -184.94
# episode  187  score -188.33  100 game average -184.71
# episode  188  score -153.89  100 game average -184.63
# episode  189  score -198.41  100 game average -182.45
# episode  190  score -317.83  100 game average -182.74
# episode  191  score -110.70  100 game average -179.52
# episode  192  score -129.33  100 game average -180.59
# episode  193  score -78.90  100 game average -177.72
# episode  194  score -129.15  100 game average -177.60
# episode  195  score -149.79  100 game average -177.93
# episode  196  score -123.53  100 game average -176.76
# episode  197  score -184.14  100 game average -177.39
# episode  198  score -161.13  100 game average -175.46
# episode  199  score -118.86  100 game average -175.47
# episode  200  score -10.44  100 game average -172.68
# episode  201  score -137.02  100 game average -169.85
# episode  202  score -157.61  100 game average -168.47
# episode  203  score -159.55  100 game average -167.56
# episode  204  score -154.41  100 game average -168.21
# episode  205  score -310.96  100 game average -168.03
# episode  206  score -219.15  100 game average -169.26
# episode  207  score -128.92  100 game average -165.76
# episode  208  score -145.70  100 game average -163.71
# episode  209  score -131.51  100 game average -163.00
# episode  210  score -96.05  100 game average -160.46
# episode  211  score -124.99  100 game average -159.43
# episode  212  score -141.28  100 game average -157.69
# episode  213  score -130.05  100 game average -157.84
# episode  214  score -169.87  100 game average -156.56
# episode  215  score -151.33  100 game average -157.03
# episode  216  score -137.52  100 game average -157.78
# episode  217  score -217.93  100 game average -158.51
# episode  218  score -141.70  100 game average -159.30
# episode  219  score -147.31  100 game average -157.17
# episode  220  score -143.43  100 game average -158.20
# episode  221  score -120.19  100 game average -158.15
# episode  222  score -148.70  100 game average -158.03
# episode  223  score -120.48  100 game average -158.39
# episode  224  score -108.37  100 game average -156.87
# episode  225  score -132.63  100 game average -157.37
# episode  226  score -154.92  100 game average -156.90
# episode  227  score -151.87  100 game average -156.94
# episode  228  score -195.27  100 game average -157.83
# episode  229  score -131.04  100 game average -156.18
# episode  230  score -125.66  100 game average -155.55
# episode  231  score -94.43  100 game average -153.49
# episode  232  score -157.88  100 game average -153.38
# episode  233  score -143.55  100 game average -152.13
# episode  234  score -96.07  100 game average -150.69
# episode  235  score -70.21  100 game average -150.65
# episode  236  score -132.91  100 game average -150.27
# episode  237  score -104.92  100 game average -149.96
# episode  238  score -137.23  100 game average -148.44
# episode  239  score -125.05  100 game average -147.46
# episode  240  score -121.10  100 game average -147.88
# episode  241  score -177.86  100 game average -147.67
# episode  242  score -154.20  100 game average -148.16
# episode  243  score -113.09  100 game average -148.16
# episode  244  score -124.27  100 game average -149.64
# episode  245  score -43.56  100 game average -148.90
# episode  246  score -141.10  100 game average -148.50
# episode  247  score -141.59  100 game average -149.13
# episode  248  score -98.69  100 game average -147.56
# episode  249  score -125.89  100 game average -147.30
# episode  250  score -137.08  100 game average -147.15
# episode  251  score -140.61  100 game average -147.94
# episode  252  score -101.50  100 game average -146.54
# episode  253  score -174.53  100 game average -145.41
# episode  254  score -165.03  100 game average -143.51
# episode  255  score -113.28  100 game average -143.56
# episode  256  score -96.31  100 game average -143.83
# episode  257  score -65.80  100 game average -140.70
# episode  258  score -160.28  100 game average -141.45
# episode  259  score -146.63  100 game average -141.23
# episode  260  score -137.51  100 game average -141.67
# episode  261  score -162.81  100 game average -141.98
# episode  262  score -181.67  100 game average -142.05
# episode  263  score -96.22  100 game average -139.47
# episode  264  score -225.94  100 game average -141.08
# episode  265  score -151.11  100 game average -141.49
# episode  266  score -130.99  100 game average -141.99
# episode  267  score -110.95  100 game average -142.19
# episode  268  score -129.24  100 game average -141.51
# episode  269  score -116.10  100 game average -141.58
# episode  270  score -170.51  100 game average -141.29
# episode  271  score -0.55  100 game average -139.62
# episode  272  score -146.58  100 game average -139.53
# episode  273  score -71.88  100 game average -139.03
# episode  274  score -202.48  100 game average -139.49
# episode  275  score -97.10  100 game average -138.98
# episode  276  score -112.42  100 game average -139.30
# episode  277  score -140.65  100 game average -138.54
# episode  278  score -133.23  100 game average -138.08
# episode  279  score -158.75  100 game average -138.19
# episode  280  score -151.66  100 game average -138.26
# episode  281  score -133.85  100 game average -137.83
# episode  282  score -133.20  100 game average -137.91
# episode  283  score -140.15  100 game average -137.64
# episode  284  score -166.94  100 game average -138.51
# episode  285  score -135.45  100 game average -138.57
# episode  286  score -116.05  100 game average -138.48
# episode  287  score 26.67  100 game average -136.33
# episode  288  score -303.36  100 game average -137.83
# episode  289  score -128.23  100 game average -137.13
# episode  290  score -133.33  100 game average -135.28
# episode  291  score -97.74  100 game average -135.15
# episode  292  score -134.92  100 game average -135.21
# episode  293  score -161.16  100 game average -136.03
# episode  294  score -124.45  100 game average -135.98
# episode  295  score -90.55  100 game average -135.39
# episode  296  score -134.25  100 game average -135.50
# episode  297  score -144.57  100 game average -135.10
# episode  298  score -84.62  100 game average -134.34
# episode  299  score -142.23  100 game average -134.57
# episode  300  score -139.54  100 game average -135.86
# episode  301  score -132.85  100 game average -135.82
# episode  302  score -355.46  100 game average -137.80
# episode  303  score -87.12  100 game average -137.08
# episode  304  score -101.40  100 game average -136.55
# episode  305  score -109.85  100 game average -134.53
# episode  306  score -138.06  100 game average -133.72
# episode  307  score -125.35  100 game average -133.69
# episode  308  score -94.32  100 game average -133.17
# episode  309  score -193.31  100 game average -133.79
# episode  310  score -179.32  100 game average -134.62
# episode  311  score -145.88  100 game average -134.83
# episode  312  score -115.45  100 game average -134.58
# episode  313  score -134.36  100 game average -134.62
# episode  314  score -148.18  100 game average -134.40
# episode  315  score -127.89  100 game average -134.17
# episode  316  score -142.98  100 game average -134.22
# episode  317  score -325.21  100 game average -135.29
# episode  318  score -234.12  100 game average -136.22
# episode  319  score -136.16  100 game average -136.11
# episode  320  score -49.42  100 game average -135.17
# episode  321  score -102.82  100 game average -134.99
# episode  322  score -140.01  100 game average -134.91
# episode  323  score -50.85  100 game average -134.21
# episode  324  score -116.32  100 game average -134.29
# episode  325  score -292.16  100 game average -135.89
# episode  326  score -104.37  100 game average -135.38
# episode  327  score -264.64  100 game average -136.51
# episode  328  score -135.19  100 game average -135.91
# episode  329  score -131.88  100 game average -135.92
# episode  330  score -349.43  100 game average -138.15
# episode  331  score -140.46  100 game average -138.61
# episode  332  score -100.30  100 game average -138.04
# episode  333  score -132.67  100 game average -137.93
# episode  334  score -105.53  100 game average -138.02
# episode  335  score -277.59  100 game average -140.10
# episode  336  score -132.04  100 game average -140.09
# episode  337  score -145.24  100 game average -140.49
# episode  338  score 14.11  100 game average -138.98
# episode  339  score -147.23  100 game average -139.20
# episode  340  score -145.58  100 game average -139.44
# episode  341  score -335.20  100 game average -141.02
# episode  342  score -186.98  100 game average -141.35
# episode  343  score -149.25  100 game average -141.71
# episode  344  score -146.57  100 game average -141.93
# episode  345  score -337.88  100 game average -144.87
# episode  346  score -330.32  100 game average -146.77
# episode  347  score -157.32  100 game average -146.92
# episode  348  score -424.76  100 game average -150.18
# episode  349  score -53.58  100 game average -149.46
# episode  350  score -108.96  100 game average -149.18
# episode  351  score -111.54  100 game average -148.89
# episode  352  score 30.70  100 game average -147.57
# episode  353  score -254.15  100 game average -148.36
# episode  354  score -249.04  100 game average -149.20
# episode  355  score -124.15  100 game average -149.31
# episode  356  score -217.79  100 game average -150.53
# episode  357  score -103.83  100 game average -150.91
# episode  358  score -328.11  100 game average -152.59
# episode  359  score -375.87  100 game average -154.88
# episode  360  score -183.45  100 game average -155.34
# episode  361  score -186.67  100 game average -155.58
# episode  362  score -296.33  100 game average -156.72
# episode  363  score -196.27  100 game average -157.72
# episode  364  score -360.68  100 game average -159.07
# episode  365  score -58.82  100 game average -158.15
# episode  366  score -133.44  100 game average -158.17
# episode  367  score -280.28  100 game average -159.87
# episode  368  score -178.60  100 game average -160.36
# episode  369  score -171.33  100 game average -160.91
# episode  370  score -166.63  100 game average -160.87
# episode  371  score -254.87  100 game average -163.42
# episode  372  score -85.96  100 game average -162.81
# episode  373  score -143.81  100 game average -163.53
# episode  374  score -260.46  100 game average -164.11
# episode  375  score -240.11  100 game average -165.54
# episode  376  score -104.75  100 game average -165.46
# episode  377  score -207.62  100 game average -166.13
# episode  378  score -344.83  100 game average -168.25
# episode  379  score -134.83  100 game average -168.01
# episode  380  score -240.86  100 game average -168.90
# episode  381  score -287.80  100 game average -170.44
# episode  382  score -129.81  100 game average -170.41
# episode  383  score -281.08  100 game average -171.82
# episode  384  score -291.78  100 game average -173.06
# episode  385  score -359.27  100 game average -175.30
# episode  386  score -151.55  100 game average -175.66
# episode  387  score -151.36  100 game average -177.44
# episode  388  score -454.90  100 game average -178.95
# episode  389  score -136.79  100 game average -179.04
# episode  390  score -52.31  100 game average -178.23
# episode  391  score -33.05  100 game average -177.58
# episode  392  score -134.37  100 game average -177.58
# episode  393  score -273.97  100 game average -178.70
# episode  394  score -60.73  100 game average -178.07
# episode  395  score -21.71  100 game average -177.38
# episode  396  score -179.30  100 game average -177.83
# episode  397  score -293.63  100 game average -179.32
# episode  398  score -51.67  100 game average -178.99
# episode  399  score -288.77  100 game average -180.45
# episode  400  score -341.24  100 game average -182.47
# episode  401  score -383.14  100 game average -184.97
# episode  402  score -321.46  100 game average -184.63
# episode  403  score -210.34  100 game average -185.87
# episode  404  score -368.91  100 game average -188.54
# episode  405  score -296.04  100 game average -190.40
# episode  406  score -30.77  100 game average -189.33
# episode  407  score -269.31  100 game average -190.77
# episode  408  score -403.35  100 game average -193.86
# episode  409  score -211.86  100 game average -194.05
# episode  410  score -393.62  100 game average -196.19
# episode  411  score -313.27  100 game average -197.86
# episode  412  score -313.99  100 game average -199.85
# episode  413  score -278.38  100 game average -201.29
# episode  414  score -353.08  100 game average -203.34
# episode  415  score -358.15  100 game average -205.64
# episode  416  score -373.17  100 game average -207.94
# episode  417  score -283.62  100 game average -207.53
# episode  418  score -396.65  100 game average -209.15
# episode  419  score -271.60  100 game average -210.51
# episode  420  score -3.08  100 game average -210.04
# episode  421  score -347.11  100 game average -212.49
# episode  422  score -282.29  100 game average -213.91
# episode  423  score -322.05  100 game average -216.62
# episode  424  score -376.04  100 game average -219.22
# episode  425  score -231.19  100 game average -218.61
# episode  426  score -277.16  100 game average -220.34
# episode  427  score -293.33  100 game average -220.62
# episode  428  score -346.36  100 game average -222.73
# episode  429  score -278.87  100 game average -224.20
# episode  430  score -73.49  100 game average -221.45
# episode  431  score -315.38  100 game average -223.19
# episode  432  score -298.77  100 game average -225.18
# episode  433  score -156.65  100 game average -225.42
# episode  434  score -107.52  100 game average -225.44
# episode  435  score -77.97  100 game average -223.44
# episode  436  score -136.61  100 game average -223.49
# episode  437  score -376.66  100 game average -225.80
# episode  438  score -241.49  100 game average -228.36
# episode  439  score -243.14  100 game average -229.32
# episode  440  score -184.45  100 game average -229.71
# episode  441  score -348.01  100 game average -229.83
# episode  442  score -169.12  100 game average -229.66
# episode  443  score -111.58  100 game average -229.28
# episode  444  score -265.11  100 game average -230.46
# episode  445  score -428.38  100 game average -231.37
# episode  446  score -103.79  100 game average -229.10
# episode  447  score -232.21  100 game average -229.85
# episode  448  score -278.71  100 game average -228.39
# episode  449  score -281.02  100 game average -230.67
# episode  450  score -354.44  100 game average -233.12
# episode  451  score -117.52  100 game average -233.18
# episode  452  score -384.47  100 game average -237.33
# episode  453  score -105.01  100 game average -235.84
# episode  454  score -219.75  100 game average -235.55
# episode  455  score -316.93  100 game average -237.48
# episode  456  score -329.36  100 game average -238.59
# episode  457  score -276.25  100 game average -240.32
# episode  458  score -335.37  100 game average -240.39
# episode  459  score -114.30  100 game average -237.77
# episode  460  score -394.31  100 game average -239.88
# episode  461  score -465.02  100 game average -242.67
# episode  462  score -390.04  100 game average -243.60
# episode  463  score -340.42  100 game average -245.04
# episode  464  score -357.97  100 game average -245.02
# episode  465  score -379.64  100 game average -248.23
# episode  466  score -304.80  100 game average -249.94
# episode  467  score -50.05  100 game average -247.64
# episode  468  score -316.61  100 game average -249.02
# episode  469  score -202.20  100 game average -249.33
# episode  470  score -268.57  100 game average -250.34
# episode  471  score -292.13  100 game average -250.72
# episode  472  score -458.64  100 game average -254.44
# episode  473  score -185.53  100 game average -254.86
# episode  474  score -140.10  100 game average -253.66
# episode  475  score -311.30  100 game average -254.37
# episode  476  score -342.02  100 game average -256.74
# episode  477  score -250.55  100 game average -257.17
# episode  478  score -294.91  100 game average -256.67
# episode  479  score -304.87  100 game average -258.37
# episode  480  score -240.32  100 game average -258.37
# episode  481  score -134.36  100 game average -256.83
# episode  482  score -400.53  100 game average -259.54
# episode  483  score -353.53  100 game average -260.27
# episode  484  score -362.24  100 game average -260.97
# episode  485  score -226.32  100 game average -259.64
# episode  486  score -359.26  100 game average -261.72
# episode  487  score -218.06  100 game average -262.38
# episode  488  score -286.87  100 game average -260.70
# episode  489  score -977.76  100 game average -269.11
# episode  490  score -202.81  100 game average -270.62
# episode  491  score -229.37  100 game average -272.58
# episode  492  score -154.54  100 game average -272.78
# episode  493  score -349.04  100 game average -273.53
# episode  494  score -383.82  100 game average -276.77
# episode  495  score -87.87  100 game average -277.43
# episode  496  score -267.88  100 game average -278.31
# episode  497  score -414.48  100 game average -279.52
# episode  498  score -102.37  100 game average -280.03
# episode  499  score -122.52  100 game average -278.37
# episode  500  score -353.08  100 game average -278.48
# episode  501  score -391.73  100 game average -278.57
# episode  502  score -361.06  100 game average -278.97
# episode  503  score -258.36  100 game average -279.45
# episode  504  score -433.00  100 game average -280.09
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 211>()
#     217 index+=1
#     218 new_state, reward, done, info = env.step(action)
# --> 219 agent.remember(obs, action, reward, new_state, int(done))
#     220 if index > start_updates and index % update_steps == 0:
#     221     agent.update()
#
# Input In [3], in Agent.remember(self, s, a, r, ns, done)
#     138 def remember(self, s, a, r, ns, done):
# --> 139     self.buffer.store_transition(s,a,r,ns,done)
#
# Input In [3], in SACBuffer.store_transition(self, state, action, reward, new_state, done)
#      11 def store_transition(self, state, action, reward, new_state, done):
#      12     self.index = self.counter % self.mem_size
# ---> 13     self.states_memory[index] = state
#      14     self.actions_memory[index] = action
#      15     self.rewards_memory[index] = reward
#
# IndexError: index 50000 is out of bounds for axis 0 with size 50000
