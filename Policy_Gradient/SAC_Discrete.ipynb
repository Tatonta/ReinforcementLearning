# %%
import copy

import torch
import gym
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter
from torch.distributions import Normal
from torch.distributions import Categorical
import itertools

# %%
class SACBuffer:
    def __init__(self, max_size, input_shape):
        self.mem_size = max_size
        self.counter = 0
        self.states_memory = np.zeros((self.mem_size, *input_shape))
        self.actions_memory = np.zeros(self.mem_size).astype(np.int64)
        self.new_states_memory = np.zeros((self.mem_size, *input_shape))
        self.rewards_memory = np.zeros(self.mem_size)
        self.dones = np.zeros(self.mem_size).astype(np.int64)

    def store_transition(self, state, action, reward, new_state, done):
        self.index = self.counter % self.mem_size
        self.states_memory[self.index] = state
        self.actions_memory[self.index] = action
        self.rewards_memory[self.index] = reward
        self.new_states_memory[self.index] = new_state
        self.dones[self.index] = done
        self.counter += 1

    def sample_buffer(self, batch_size):
        max_mem = self.counter
        if self.counter > self.mem_size:
            max_mem = self.mem_size
        batch = np.random.choice(max_mem, batch_size)

        states = self.states_memory[batch]
        rewards = self.rewards_memory[batch]
        new_states = self.new_states_memory[batch]
        actions = self.actions_memory[batch]
        dones = self.dones[batch]

        return states, rewards, actions, new_states, dones

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class ActionEstimator(nn.Module):
    def __init__(self, input_dims, actions, hidden_sizes):
        super(ActionEstimator, self).__init__()
        self.hidden_sizes = hidden_sizes
        self.reparam_noise = 1e-6
        self.SeqLayer = nn.Sequential(
            nn.Linear(*input_dims, hidden_sizes[0]),
            nn.ReLU(),
            nn.Linear(hidden_sizes[0], hidden_sizes[1]),
            nn.ReLU(),
            nn.Linear(hidden_sizes[1], actions),
            nn.Softmax(dim=1)
        )

    def forward(self, state):
        action_dist = self.SeqLayer(state)
        log_probs = torch.log(action_dist+self.reparam_noise)
        return action_dist, log_probs

    def act(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        action_dist, log_probs = self.forward(state)
        m = Categorical(action_dist)
        action = m.sample()
        return action.item()

class Q_Net(nn.Module):
    def __init__(self, input_dims, actions, hidden_sizes):
        super(Q_Net, self).__init__()
        self.hidden_sizes = hidden_sizes
        self.SeqLayer = nn.Sequential(
            nn.Linear(*input_dims, self.hidden_sizes[0]),
            nn.ReLU(),
            nn.Linear(self.hidden_sizes[0], self.hidden_sizes[1]),
            nn.ReLU(),
            nn.Linear(self.hidden_sizes[1], actions)
        )

    def forward(self, state):
        Q_values = self.SeqLayer(state)
        return Q_values

# %%
class Agent:
    def __init__(self, n_actions, input_dims, hidden_sizes = [256, 256], gamma=0.95, batch_size=256):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.gamma = gamma
        self.batch_size = batch_size
        self.tau = 0.01
        self.ALPHA_INITIAL = 1
        self.actor = ActionEstimator(input_dims, n_actions, hidden_sizes).to(self.device)
        self.Q1 = Q_Net(input_dims, n_actions, hidden_sizes).to(self.device)
        self.Q2 = Q_Net(input_dims, n_actions, hidden_sizes).to(self.device)
        self.Q1_targ = copy.deepcopy(self.Q1)
        self.Q2_targ = copy.deepcopy(self.Q2)

        self.buffer = SACBuffer(50000, input_shape = input_dims)
        self.MSE_Criterion = nn.MSELoss()

        self.q1_optim = torch.optim.Adam(self.Q1.parameters(), lr=1e-4)
        self.q2_optim = torch.optim.Adam(self.Q2.parameters(), lr=1e-4)
        self.actor_optim = torch.optim.Adam(self.actor.parameters(), lr=1e-4)
        self.q_targ_p = itertools.chain(self.Q1_targ.parameters(), self.Q2_targ.parameters())
        for parameter in self.q_targ_p:
            parameter.requires_grad = False

        self.target_entropy = 0.98 * -np.log(1 / n_actions)
        self.log_alpha = torch.tensor(np.log(self.ALPHA_INITIAL), requires_grad=True)
        self.alpha = self.log_alpha
        self.alpha_optimizer = torch.optim.Adam([self.log_alpha], lr=1e-4)

    def choose_action(self, state):
        action = self.actor.act(state)
        return action

    def update_network_parameters(self):
        for target_param, param in zip(self.Q1_targ.parameters(), self.Q1.parameters()):
            target_param.data.copy_(self.tau*param.data + (1-self.tau)*target_param.data)

        for target_param, param in zip(self.Q2_targ.parameters(), self.Q2.parameters()):
            target_param.data.copy_(self.tau*param.data + (1-self.tau)*target_param.data)

    def remember(self, s, a, r, ns, done):
        self.buffer.store_transition(s,a,r,ns,done)

    def update(self):
        if self.buffer.counter < self.batch_size:
            return
        states, rewards, actions, new_states, dones = self.buffer.sample_buffer(self.batch_size)

        states_t = torch.from_numpy(states).float().to(self.device)
        rewards_t = torch.from_numpy(rewards).float().to(self.device)
        actions_t = torch.from_numpy(actions).to(self.device)
        new_states_t = torch.from_numpy(new_states).float().to(self.device)
        dones_t = torch.from_numpy(dones).to(self.device)


        self.q1_optim.zero_grad()
        self.q2_optim.zero_grad()
        self.actor_optim.zero_grad()
        self.alpha_optimizer.zero_grad()
        q1 = self.Q1(states_t).gather(1, actions_t.unsqueeze(-1)).squeeze(-1)
        q2 = self.Q2(states_t).gather(1, actions_t.unsqueeze(-1)).squeeze(-1)
        with torch.no_grad():
            actions_probs, log_probs = self.actor(new_states_t)
            q1t_value = self.Q1_targ(new_states_t)
            q2t_value = self.Q2_targ(new_states_t)
            predicted_new_q = torch.min(q1t_value, q2t_value)
            backup = rewards_t + self.gamma * (1 - dones_t) * (actions_probs * (predicted_new_q - self.alpha * log_probs)).sum(dim=-1)

        loss_q1 = self.MSE_Criterion(q1, backup)
        loss_q2 = self.MSE_Criterion(q2, backup)
        loss_q1.backward()
        loss_q2.backward()
        self.q1_optim.step()
        self.q2_optim.step()

        # LOSS FOR ACTOR
        action_dist, log_probs = self.actor(states_t)
        q1_new_policy = self.Q1(states_t)
        q2_new_policy = self.Q2(states_t)
        qp_min = torch.min(q1_new_policy, q2_new_policy)
        pi_loss = (action_dist*(self.alpha * log_probs - qp_min)).sum(dim=-1).mean()
        pi_loss.backward()
        self.actor_optim.step()

        alpha_loss = -(self.log_alpha * (log_probs + self.target_entropy).detach()).mean()
        alpha_loss.backward()
        self.alpha_optimizer.step()
        self.alpha = self.log_alpha.exp()
        # Updating Policy

        # Finally, update target networks by polyak averaging.
        # with torch.no_grad():
        #     for p_targ, p in zip(self.V_targ_params, self.V_params):
        #         # NB: We use an in-place operations "mul_", "add_" to update target
        #         # params, as opposed to "mul" and "add", which would make new tensors.
        #         p_targ.data.mul_(self.polyak)
        #         p_targ.data.add_((1 - self.polyak) * p.data)

        self.update_network_parameters()

env = gym.make("CartPole-v1")
writer = SummaryWriter()
n_actions = env.action_space.n
obs_dim = env.observation_space.shape
n_games = 4000
agent = Agent(n_actions, obs_dim)
exploration_end = 10000
start_updates = 1000
update_steps = 50
index = 0
eps_rewards = []
updating = 0
for i in range(n_games):
    done = False
    score = 0
    obs = env.reset()
    while not done:
        # if index < exploration_end:
        #     action = env.action_space.sample()
        # else:
        action = agent.choose_action(obs)
        index+=1
        new_state, reward, done, info = env.step(action)
        agent.remember(obs, action, reward, new_state, done)
        if index > start_updates:
            agent.update()
        score += reward
        obs = new_state
    eps_rewards.append(score)
    avg_score = np.mean(eps_rewards[-100:])
    writer.add_scalar("Episode total reward", eps_rewards[i], i)

    print('episode ', i, " score %.2f " %score,
          "100 game average %.2f" % avg_score)
# Out:
# episode  0  score 20.00  100 game average 20.00
# episode  1  score 18.00  100 game average 19.00
# episode  2  score 10.00  100 game average 16.00
# episode  3  score 23.00  100 game average 17.75
# episode  4  score 15.00  100 game average 17.20
# episode  5  score 27.00  100 game average 18.83
# episode  6  score 11.00  100 game average 17.71
# episode  7  score 14.00  100 game average 17.25
# episode  8  score 26.00  100 game average 18.22
# episode  9  score 17.00  100 game average 18.10
# episode  10  score 11.00  100 game average 17.45
# episode  11  score 13.00  100 game average 17.08
# episode  12  score 10.00  100 game average 16.54
# episode  13  score 19.00  100 game average 16.71
# episode  14  score 16.00  100 game average 16.67
# episode  15  score 64.00  100 game average 19.62
# episode  16  score 21.00  100 game average 19.71
# episode  17  score 13.00  100 game average 19.33
# episode  18  score 17.00  100 game average 19.21
# episode  19  score 15.00  100 game average 19.00
# episode  20  score 24.00  100 game average 19.24
# episode  21  score 47.00  100 game average 20.50
# episode  22  score 21.00  100 game average 20.52
# episode  23  score 12.00  100 game average 20.17
# episode  24  score 10.00  100 game average 19.76
# episode  25  score 18.00  100 game average 19.69
# episode  26  score 22.00  100 game average 19.78
# episode  27  score 20.00  100 game average 19.79
# episode  28  score 27.00  100 game average 20.03
# episode  29  score 35.00  100 game average 20.53
# episode  30  score 32.00  100 game average 20.90
# episode  31  score 23.00  100 game average 20.97
# episode  32  score 39.00  100 game average 21.52
# episode  33  score 20.00  100 game average 21.47
# episode  34  score 29.00  100 game average 21.69
# episode  35  score 34.00  100 game average 22.03
# episode  36  score 19.00  100 game average 21.95
# episode  37  score 20.00  100 game average 21.89
# episode  38  score 11.00  100 game average 21.62
# episode  39  score 65.00  100 game average 22.70
# episode  40  score 15.00  100 game average 22.51
# episode  41  score 13.00  100 game average 22.29
# episode  42  score 19.00  100 game average 22.21
# episode  43  score 40.00  100 game average 22.61
# episode  44  score 23.00  100 game average 22.62
# episode  45  score 23.00  100 game average 22.63
# episode  46  score 11.00  100 game average 22.38
# episode  47  score 16.00  100 game average 22.25
# episode  48  score 35.00  100 game average 22.51
# episode  49  score 23.00  100 game average 22.52
# episode  50  score 19.00  100 game average 22.45
# episode  51  score 23.00  100 game average 22.46
# episode  52  score 15.00  100 game average 22.32
# episode  53  score 20.00  100 game average 22.28
# episode  54  score 14.00  100 game average 22.13
# episode  55  score 23.00  100 game average 22.14
# episode  56  score 15.00  100 game average 22.02
# episode  57  score 18.00  100 game average 21.95
# episode  58  score 27.00  100 game average 22.03
# episode  59  score 13.00  100 game average 21.88
# episode  60  score 18.00  100 game average 21.82
# episode  61  score 63.00  100 game average 22.48
# episode  62  score 14.00  100 game average 22.35
# episode  63  score 34.00  100 game average 22.53
# episode  64  score 34.00  100 game average 22.71
# episode  65  score 17.00  100 game average 22.62
# episode  66  score 33.00  100 game average 22.78
# episode  67  score 14.00  100 game average 22.65
# episode  68  score 21.00  100 game average 22.62
# episode  69  score 35.00  100 game average 22.80
# episode  70  score 25.00  100 game average 22.83
# episode  71  score 28.00  100 game average 22.90
# episode  72  score 106.00  100 game average 24.04
# episode  73  score 20.00  100 game average 23.99
# episode  74  score 36.00  100 game average 24.15
# episode  75  score 37.00  100 game average 24.32
# episode  76  score 66.00  100 game average 24.86
# episode  77  score 34.00  100 game average 24.97
# episode  78  score 25.00  100 game average 24.97
# episode  79  score 70.00  100 game average 25.54
# episode  80  score 85.00  100 game average 26.27
# episode  81  score 91.00  100 game average 27.06
# episode  82  score 103.00  100 game average 27.98
# episode  83  score 72.00  100 game average 28.50
# episode  84  score 191.00  100 game average 30.41
# episode  85  score 65.00  100 game average 30.81
# episode  86  score 198.00  100 game average 32.74
# episode  87  score 132.00  100 game average 33.86
# episode  88  score 287.00  100 game average 36.71
# episode  89  score 199.00  100 game average 38.51
# episode  90  score 151.00  100 game average 39.75
# episode  91  score 244.00  100 game average 41.97
# episode  92  score 179.00  100 game average 43.44
# episode  93  score 371.00  100 game average 46.93
# episode  94  score 265.00  100 game average 49.22
# episode  95  score 286.00  100 game average 51.69
# episode  96  score 219.00  100 game average 53.41
# episode  97  score 240.00  100 game average 55.32
# episode  98  score 353.00  100 game average 58.32
# episode  99  score 380.00  100 game average 61.54
# episode  100  score 248.00  100 game average 63.82
# episode  101  score 225.00  100 game average 65.89
# episode  102  score 353.00  100 game average 69.32
# episode  103  score 327.00  100 game average 72.36
# episode  104  score 210.00  100 game average 74.31
# episode  105  score 292.00  100 game average 76.96
# episode  106  score 337.00  100 game average 80.22
# episode  107  score 328.00  100 game average 83.36
# episode  108  score 184.00  100 game average 84.94
# episode  109  score 320.00  100 game average 87.97
# episode  110  score 242.00  100 game average 90.28
# episode  111  score 226.00  100 game average 92.41
# episode  112  score 207.00  100 game average 94.38
# episode  113  score 141.00  100 game average 95.60
# episode  114  score 222.00  100 game average 97.66
# episode  115  score 254.00  100 game average 99.56
# episode  116  score 189.00  100 game average 101.24
# episode  117  score 256.00  100 game average 103.67
# episode  118  score 310.00  100 game average 106.60
# episode  119  score 202.00  100 game average 108.47
# episode  120  score 238.00  100 game average 110.61
# episode  121  score 301.00  100 game average 113.15
# episode  122  score 229.00  100 game average 115.23
# episode  123  score 221.00  100 game average 117.32
# episode  124  score 214.00  100 game average 119.36
# episode  125  score 213.00  100 game average 121.31
# episode  126  score 270.00  100 game average 123.79
# episode  127  score 216.00  100 game average 125.75
# episode  128  score 220.00  100 game average 127.68
# episode  129  score 201.00  100 game average 129.34
# episode  130  score 273.00  100 game average 131.75
# episode  131  score 345.00  100 game average 134.97
# episode  132  score 219.00  100 game average 136.77
# episode  133  score 262.00  100 game average 139.19
# episode  134  score 249.00  100 game average 141.39
# episode  135  score 291.00  100 game average 143.96
# episode  136  score 55.00  100 game average 144.32
# episode  137  score 219.00  100 game average 146.31
# episode  138  score 419.00  100 game average 150.39
# episode  139  score 341.00  100 game average 153.15
# episode  140  score 275.00  100 game average 155.75
# episode  141  score 206.00  100 game average 157.68
# episode  142  score 187.00  100 game average 159.36
# episode  143  score 283.00  100 game average 161.79
# episode  144  score 243.00  100 game average 163.99
# episode  145  score 500.00  100 game average 168.76
# episode  146  score 175.00  100 game average 170.40
# episode  147  score 266.00  100 game average 172.90
# episode  148  score 254.00  100 game average 175.09
# episode  149  score 301.00  100 game average 177.87
# episode  150  score 322.00  100 game average 180.90
# episode  151  score 198.00  100 game average 182.65
# episode  152  score 240.00  100 game average 184.90
# episode  153  score 207.00  100 game average 186.77
# episode  154  score 223.00  100 game average 188.86
# episode  155  score 188.00  100 game average 190.51
# episode  156  score 211.00  100 game average 192.47
# episode  157  score 221.00  100 game average 194.50
# episode  158  score 84.00  100 game average 195.07
# episode  159  score 38.00  100 game average 195.32
# episode  160  score 184.00  100 game average 196.98
# episode  161  score 225.00  100 game average 198.60
# episode  162  score 389.00  100 game average 202.35
# episode  163  score 229.00  100 game average 204.30
# episode  164  score 288.00  100 game average 206.84
# episode  165  score 234.00  100 game average 209.01
# episode  166  score 170.00  100 game average 210.38
# episode  167  score 207.00  100 game average 212.31
# episode  168  score 294.00  100 game average 215.04
# episode  169  score 159.00  100 game average 216.28
# episode  170  score 276.00  100 game average 218.79
# episode  171  score 204.00  100 game average 220.55
# episode  172  score 280.00  100 game average 222.29
# episode  173  score 199.00  100 game average 224.08
# episode  174  score 191.00  100 game average 225.63
# episode  175  score 28.00  100 game average 225.54
# episode  176  score 89.00  100 game average 225.77
# episode  177  score 199.00  100 game average 227.42
# episode  178  score 302.00  100 game average 230.19
# episode  179  score 207.00  100 game average 231.56
# episode  180  score 295.00  100 game average 233.66
# episode  181  score 226.00  100 game average 235.01
# episode  182  score 235.00  100 game average 236.33
# episode  183  score 136.00  100 game average 236.97
# episode  184  score 396.00  100 game average 239.02
# episode  185  score 167.00  100 game average 240.04
# episode  186  score 147.00  100 game average 239.53
# episode  187  score 97.00  100 game average 239.18
# episode  188  score 194.00  100 game average 238.25
# episode  189  score 316.00  100 game average 239.42
# episode  190  score 288.00  100 game average 240.79
# episode  191  score 180.00  100 game average 240.15
# episode  192  score 196.00  100 game average 240.32
# episode  193  score 180.00  100 game average 238.41
# episode  194  score 252.00  100 game average 238.28
# episode  195  score 250.00  100 game average 237.92
# episode  196  score 192.00  100 game average 237.65
# episode  197  score 321.00  100 game average 238.46
# episode  198  score 117.00  100 game average 236.10
# episode  199  score 329.00  100 game average 235.59
# episode  200  score 202.00  100 game average 235.13
# episode  201  score 230.00  100 game average 235.18
# episode  202  score 411.00  100 game average 235.76
# episode  203  score 378.00  100 game average 236.27
# episode  204  score 197.00  100 game average 236.14
# episode  205  score 89.00  100 game average 234.11
# episode  206  score 191.00  100 game average 232.65
# episode  207  score 286.00  100 game average 232.23
# episode  208  score 256.00  100 game average 232.95
# episode  209  score 161.00  100 game average 231.36
# episode  210  score 135.00  100 game average 230.29
# episode  211  score 228.00  100 game average 230.31
# episode  212  score 177.00  100 game average 230.01
# episode  213  score 168.00  100 game average 230.28
# episode  214  score 172.00  100 game average 229.78
# episode  215  score 91.00  100 game average 228.15
# episode  216  score 213.00  100 game average 228.39
# episode  217  score 142.00  100 game average 227.25
# episode  218  score 230.00  100 game average 226.45
# episode  219  score 196.00  100 game average 226.39
# episode  220  score 184.00  100 game average 225.85
# episode  221  score 383.00  100 game average 226.67
# episode  222  score 293.00  100 game average 227.31
# episode  223  score 17.00  100 game average 225.27
# episode  224  score 165.00  100 game average 224.78
# episode  225  score 76.00  100 game average 223.41
# episode  226  score 187.00  100 game average 222.58
# episode  227  score 23.00  100 game average 220.65
# episode  228  score 216.00  100 game average 220.61
# episode  229  score 198.00  100 game average 220.58
# episode  230  score 235.00  100 game average 220.20
# episode  231  score 25.00  100 game average 217.00
# episode  232  score 92.00  100 game average 215.73
# episode  233  score 46.00  100 game average 213.57
# episode  234  score 80.00  100 game average 211.88
# episode  235  score 161.00  100 game average 210.58
# episode  236  score 244.00  100 game average 212.47
# episode  237  score 262.00  100 game average 212.90
# episode  238  score 232.00  100 game average 211.03
# episode  239  score 145.00  100 game average 209.07
# episode  240  score 293.00  100 game average 209.25
# episode  241  score 254.00  100 game average 209.73
# episode  242  score 291.00  100 game average 210.77
# episode  243  score 497.00  100 game average 212.91
# episode  244  score 210.00  100 game average 212.58
# episode  245  score 245.00  100 game average 210.03
# episode  246  score 96.00  100 game average 209.24
# episode  247  score 174.00  100 game average 208.32
# episode  248  score 257.00  100 game average 208.35
# episode  249  score 299.00  100 game average 208.33
# episode  250  score 192.00  100 game average 207.03
# episode  251  score 76.00  100 game average 205.81
# episode  252  score 236.00  100 game average 205.77
# episode  253  score 260.00  100 game average 206.30
# episode  254  score 184.00  100 game average 205.91
# episode  255  score 186.00  100 game average 205.89
# episode  256  score 244.00  100 game average 206.22
# episode  257  score 234.00  100 game average 206.35
# episode  258  score 154.00  100 game average 207.05
# episode  259  score 251.00  100 game average 209.18
# episode  260  score 61.00  100 game average 207.95
# episode  261  score 199.00  100 game average 207.69
# episode  262  score 325.00  100 game average 207.05
# episode  263  score 201.00  100 game average 206.77
# episode  264  score 202.00  100 game average 205.91
# episode  265  score 159.00  100 game average 205.16
# episode  266  score 273.00  100 game average 206.19
# episode  267  score 295.00  100 game average 207.07
# episode  268  score 155.00  100 game average 205.68
# episode  269  score 145.00  100 game average 205.54
# episode  270  score 151.00  100 game average 204.29
# episode  271  score 400.00  100 game average 206.25
# episode  272  score 231.00  100 game average 205.76
# episode  273  score 257.00  100 game average 206.34
# episode  274  score 101.00  100 game average 205.44
# episode  275  score 95.00  100 game average 206.11
# episode  276  score 157.00  100 game average 206.79
# episode  277  score 265.00  100 game average 207.45
# episode  278  score 80.00  100 game average 205.23
# episode  279  score 273.00  100 game average 205.89
# episode  280  score 135.00  100 game average 204.29
# episode  281  score 191.00  100 game average 203.94
# episode  282  score 82.00  100 game average 202.41
# episode  283  score 120.00  100 game average 202.25
# episode  284  score 56.00  100 game average 198.85
# episode  285  score 125.00  100 game average 198.43
# episode  286  score 25.00  100 game average 197.21
# episode  287  score 154.00  100 game average 197.78
# episode  288  score 136.00  100 game average 197.20
# episode  289  score 80.00  100 game average 194.84
# episode  290  score 177.00  100 game average 193.73
# episode  291  score 264.00  100 game average 194.57
# episode  292  score 33.00  100 game average 192.94
# episode  293  score 247.00  100 game average 193.61
# episode  294  score 17.00  100 game average 191.26
# episode  295  score 175.00  100 game average 190.51
# episode  296  score 226.00  100 game average 190.85
# episode  297  score 225.00  100 game average 189.89
# episode  298  score 144.00  100 game average 190.16
# episode  299  score 323.00  100 game average 190.10
# episode  300  score 146.00  100 game average 189.54
# episode  301  score 131.00  100 game average 188.55
# episode  302  score 252.00  100 game average 186.96
# episode  303  score 168.00  100 game average 184.86
# episode  304  score 251.00  100 game average 185.40
# episode  305  score 275.00  100 game average 187.26
# episode  306  score 296.00  100 game average 188.31
# episode  307  score 166.00  100 game average 187.11
# episode  308  score 17.00  100 game average 184.72
# episode  309  score 101.00  100 game average 184.12
# episode  310  score 130.00  100 game average 184.07
# episode  311  score 159.00  100 game average 183.38
# episode  312  score 205.00  100 game average 183.66
# episode  313  score 330.00  100 game average 185.28
# episode  314  score 500.00  100 game average 188.56
# episode  315  score 114.00  100 game average 188.79
# episode  316  score 93.00  100 game average 187.59
# episode  317  score 172.00  100 game average 187.89
# episode  318  score 270.00  100 game average 188.29
# episode  319  score 107.00  100 game average 187.40
# episode  320  score 258.00  100 game average 188.14
# episode  321  score 179.00  100 game average 186.10
# episode  322  score 154.00  100 game average 184.71
# episode  323  score 184.00  100 game average 186.38
# episode  324  score 213.00  100 game average 186.86
# episode  325  score 190.00  100 game average 188.00
# episode  326  score 168.00  100 game average 187.81
# episode  327  score 139.00  100 game average 188.97
# episode  328  score 28.00  100 game average 187.09
# episode  329  score 51.00  100 game average 185.62
# episode  330  score 130.00  100 game average 184.57
# episode  331  score 12.00  100 game average 184.44
# episode  332  score 174.00  100 game average 185.26
# episode  333  score 192.00  100 game average 186.72
# episode  334  score 28.00  100 game average 186.20
# episode  335  score 44.00  100 game average 185.03
# episode  336  score 38.00  100 game average 182.97
# episode  337  score 146.00  100 game average 181.81
# episode  338  score 20.00  100 game average 179.69
# episode  339  score 225.00  100 game average 180.49
# episode  340  score 116.00  100 game average 178.72
# episode  341  score 123.00  100 game average 177.41
# episode  342  score 35.00  100 game average 174.85
# episode  343  score 204.00  100 game average 171.92
# episode  344  score 245.00  100 game average 172.27
# episode  345  score 203.00  100 game average 171.85
# episode  346  score 21.00  100 game average 171.10
# episode  347  score 195.00  100 game average 171.31
# episode  348  score 87.00  100 game average 169.61
# episode  349  score 35.00  100 game average 166.97
# episode  350  score 42.00  100 game average 165.47
# episode  351  score 18.00  100 game average 164.89
# episode  352  score 114.00  100 game average 163.67
# episode  353  score 118.00  100 game average 162.25
# episode  354  score 223.00  100 game average 162.64
# episode  355  score 81.00  100 game average 161.59
# episode  356  score 59.00  100 game average 159.74
# episode  357  score 73.00  100 game average 158.13
# episode  358  score 200.00  100 game average 158.59
# episode  359  score 28.00  100 game average 156.36
# episode  360  score 169.00  100 game average 157.44
# episode  361  score 56.00  100 game average 156.01
# episode  362  score 355.00  100 game average 156.31
# episode  363  score 63.00  100 game average 154.93
# episode  364  score 166.00  100 game average 154.57
# episode  365  score 195.00  100 game average 154.93
# episode  366  score 141.00  100 game average 153.61
# episode  367  score 337.00  100 game average 154.03
# episode  368  score 47.00  100 game average 152.95
# episode  369  score 26.00  100 game average 151.76
# episode  370  score 94.00  100 game average 151.19
# episode  371  score 186.00  100 game average 149.05
# episode  372  score 160.00  100 game average 148.34
# episode  373  score 177.00  100 game average 147.54
# episode  374  score 98.00  100 game average 147.51
# episode  375  score 101.00  100 game average 147.57
# episode  376  score 119.00  100 game average 147.19
# episode  377  score 120.00  100 game average 145.74
# episode  378  score 174.00  100 game average 146.68
# episode  379  score 205.00  100 game average 146.00
# episode  380  score 145.00  100 game average 146.10
# episode  381  score 14.00  100 game average 144.33
# episode  382  score 197.00  100 game average 145.48
# episode  383  score 24.00  100 game average 144.52
# episode  384  score 15.00  100 game average 144.11
# episode  385  score 99.00  100 game average 143.85
# episode  386  score 64.00  100 game average 144.24
# episode  387  score 90.00  100 game average 143.60
# episode  388  score 17.00  100 game average 142.41
# episode  389  score 161.00  100 game average 143.22
# episode  390  score 96.00  100 game average 142.41
# episode  391  score 133.00  100 game average 141.10
# episode  392  score 55.00  100 game average 141.32
# episode  393  score 206.00  100 game average 140.91
# episode  394  score 131.00  100 game average 142.05
# episode  395  score 182.00  100 game average 142.12
# episode  396  score 195.00  100 game average 141.81
# episode  397  score 199.00  100 game average 141.55
# episode  398  score 47.00  100 game average 140.58
# episode  399  score 182.00  100 game average 139.17
# episode  400  score 85.00  100 game average 138.56
# episode  401  score 148.00  100 game average 138.73
# episode  402  score 282.00  100 game average 139.03
# episode  403  score 21.00  100 game average 137.56
# episode  404  score 104.00  100 game average 136.09
# episode  405  score 23.00  100 game average 133.57
# episode  406  score 52.00  100 game average 131.13
# episode  407  score 33.00  100 game average 129.80
# episode  408  score 185.00  100 game average 131.48
# episode  409  score 67.00  100 game average 131.14
# episode  410  score 187.00  100 game average 131.71
# episode  411  score 53.00  100 game average 130.65
# episode  412  score 45.00  100 game average 129.05
# episode  413  score 34.00  100 game average 126.09
# episode  414  score 77.00  100 game average 121.86
# episode  415  score 107.00  100 game average 121.79
# episode  416  score 47.00  100 game average 121.33
# episode  417  score 186.00  100 game average 121.47
# episode  418  score 78.00  100 game average 119.55
# episode  419  score 41.00  100 game average 118.89
# episode  420  score 133.00  100 game average 117.64
# episode  421  score 104.00  100 game average 116.89
# episode  422  score 19.00  100 game average 115.54
# episode  423  score 14.00  100 game average 113.84
# episode  424  score 27.00  100 game average 111.98
# episode  425  score 107.00  100 game average 111.15
# episode  426  score 106.00  100 game average 110.53
# episode  427  score 221.00  100 game average 111.35
# episode  428  score 36.00  100 game average 111.43
# episode  429  score 335.00  100 game average 114.27
# episode  430  score 26.00  100 game average 113.23
# episode  431  score 59.00  100 game average 113.70
# episode  432  score 83.00  100 game average 112.79
# episode  433  score 62.00  100 game average 111.49
# episode  434  score 27.00  100 game average 111.48
# episode  435  score 38.00  100 game average 111.42
# episode  436  score 75.00  100 game average 111.79
# episode  437  score 16.00  100 game average 110.49
# episode  438  score 173.00  100 game average 112.02
# episode  439  score 16.00  100 game average 109.93
# episode  440  score 26.00  100 game average 109.03
# episode  441  score 34.00  100 game average 108.14
# episode  442  score 78.00  100 game average 108.57
# episode  443  score 147.00  100 game average 108.00
# episode  444  score 205.00  100 game average 107.60
# episode  445  score 49.00  100 game average 106.06
# episode  446  score 122.00  100 game average 107.07
# episode  447  score 153.00  100 game average 106.65
# episode  448  score 135.00  100 game average 107.13
# episode  449  score 52.00  100 game average 107.30
# episode  450  score 111.00  100 game average 107.99
# episode  451  score 167.00  100 game average 109.48
# episode  452  score 47.00  100 game average 108.81
# episode  453  score 204.00  100 game average 109.67
# episode  454  score 32.00  100 game average 107.76
# episode  455  score 15.00  100 game average 107.10
# episode  456  score 227.00  100 game average 108.78
# episode  457  score 164.00  100 game average 109.69
# episode  458  score 214.00  100 game average 109.83
# episode  459  score 74.00  100 game average 110.29
# episode  460  score 40.00  100 game average 109.00
# episode  461  score 80.00  100 game average 109.24
# episode  462  score 25.00  100 game average 105.94
# episode  463  score 53.00  100 game average 105.84
# episode  464  score 64.00  100 game average 104.82
# episode  465  score 53.00  100 game average 103.40
# episode  466  score 16.00  100 game average 102.15
# episode  467  score 82.00  100 game average 99.60
# episode  468  score 134.00  100 game average 100.47
# episode  469  score 16.00  100 game average 100.37
# episode  470  score 41.00  100 game average 99.84
# episode  471  score 174.00  100 game average 99.72
# episode  472  score 100.00  100 game average 99.12
# episode  473  score 21.00  100 game average 97.56
# episode  474  score 69.00  100 game average 97.27
# episode  475  score 51.00  100 game average 96.77
# episode  476  score 106.00  100 game average 96.64
# episode  477  score 134.00  100 game average 96.78
# episode  478  score 12.00  100 game average 95.16
# episode  479  score 161.00  100 game average 94.72
# episode  480  score 59.00  100 game average 93.86
# episode  481  score 39.00  100 game average 94.11
# episode  482  score 63.00  100 game average 92.77
# episode  483  score 40.00  100 game average 92.93
# episode  484  score 30.00  100 game average 93.08
# episode  485  score 156.00  100 game average 93.65
# episode  486  score 62.00  100 game average 93.63
# episode  487  score 10.00  100 game average 92.83
# episode  488  score 84.00  100 game average 93.50
# episode  489  score 124.00  100 game average 93.13
# episode  490  score 28.00  100 game average 92.45
# episode  491  score 85.00  100 game average 91.97
# episode  492  score 55.00  100 game average 91.97
# episode  493  score 147.00  100 game average 91.38
# episode  494  score 28.00  100 game average 90.35
# episode  495  score 14.00  100 game average 88.67
# episode  496  score 12.00  100 game average 86.84
# episode  497  score 49.00  100 game average 85.34
# episode  498  score 64.00  100 game average 85.51
# episode  499  score 46.00  100 game average 84.15
# episode  500  score 83.00  100 game average 84.13
# episode  501  score 96.00  100 game average 83.61
# episode  502  score 15.00  100 game average 80.94
# episode  503  score 132.00  100 game average 82.05
# episode  504  score 44.00  100 game average 81.45
# episode  505  score 31.00  100 game average 81.53
# episode  506  score 371.00  100 game average 84.72
# episode  507  score 60.00  100 game average 84.99
# episode  508  score 57.00  100 game average 83.71
# episode  509  score 119.00  100 game average 84.23
# episode  510  score 107.00  100 game average 83.43
# episode  511  score 31.00  100 game average 83.21
# episode  512  score 111.00  100 game average 83.87
# episode  513  score 38.00  100 game average 83.91
# episode  514  score 117.00  100 game average 84.31
# episode  515  score 16.00  100 game average 83.40
# episode  516  score 58.00  100 game average 83.51
# episode  517  score 61.00  100 game average 82.26
# episode  518  score 47.00  100 game average 81.95
# episode  519  score 105.00  100 game average 82.59
# episode  520  score 16.00  100 game average 81.42
# episode  521  score 96.00  100 game average 81.34
# episode  522  score 25.00  100 game average 81.40
# episode  523  score 44.00  100 game average 81.70
# episode  524  score 72.00  100 game average 82.15
# episode  525  score 44.00  100 game average 81.52
# episode  526  score 43.00  100 game average 80.89
# episode  527  score 112.00  100 game average 79.80
# episode  528  score 58.00  100 game average 80.02
# episode  529  score 43.00  100 game average 77.10
# episode  530  score 107.00  100 game average 77.91
# episode  531  score 44.00  100 game average 77.76
# episode  532  score 111.00  100 game average 78.04
# episode  533  score 59.00  100 game average 78.01
# episode  534  score 101.00  100 game average 78.75
# episode  535  score 51.00  100 game average 78.88
# episode  536  score 48.00  100 game average 78.61
# episode  537  score 69.00  100 game average 79.14
# episode  538  score 67.00  100 game average 78.08
# episode  539  score 114.00  100 game average 79.06
# episode  540  score 106.00  100 game average 79.86
# episode  541  score 22.00  100 game average 79.74
# episode  542  score 110.00  100 game average 80.06
# episode  543  score 42.00  100 game average 79.01
# episode  544  score 43.00  100 game average 77.39
# episode  545  score 111.00  100 game average 78.01
# episode  546  score 26.00  100 game average 77.05
# episode  547  score 58.00  100 game average 76.10
# episode  548  score 28.00  100 game average 75.03
# episode  549  score 94.00  100 game average 75.45
# episode  550  score 47.00  100 game average 74.81
# episode  551  score 37.00  100 game average 73.51
# episode  552  score 62.00  100 game average 73.66
# episode  553  score 85.00  100 game average 72.47
# episode  554  score 98.00  100 game average 73.13
# episode  555  score 212.00  100 game average 75.10
# episode  556  score 66.00  100 game average 73.49
# episode  557  score 34.00  100 game average 72.19
# episode  558  score 25.00  100 game average 70.30
# episode  559  score 46.00  100 game average 70.02
# episode  560  score 26.00  100 game average 69.88
# episode  561  score 30.00  100 game average 69.38
# episode  562  score 55.00  100 game average 69.68
# episode  563  score 18.00  100 game average 69.33
# episode  564  score 38.00  100 game average 69.07
# episode  565  score 29.00  100 game average 68.83
# episode  566  score 134.00  100 game average 70.01
# episode  567  score 24.00  100 game average 69.43
# episode  568  score 22.00  100 game average 68.31
# episode  569  score 99.00  100 game average 69.14
# episode  570  score 40.00  100 game average 69.13
# episode  571  score 50.00  100 game average 67.89
# episode  572  score 14.00  100 game average 67.03
# episode  573  score 23.00  100 game average 67.05
# episode  574  score 100.00  100 game average 67.36
# episode  575  score 65.00  100 game average 67.50
# episode  576  score 62.00  100 game average 67.06
# episode  577  score 118.00  100 game average 66.90
# episode  578  score 54.00  100 game average 67.32
# episode  579  score 48.00  100 game average 66.19
# episode  580  score 137.00  100 game average 66.97
# episode  581  score 17.00  100 game average 66.75
# episode  582  score 54.00  100 game average 66.66
# episode  583  score 20.00  100 game average 66.46
# episode  584  score 41.00  100 game average 66.57
# episode  585  score 65.00  100 game average 65.66
# episode  586  score 102.00  100 game average 66.06
# episode  587  score 121.00  100 game average 67.17
# episode  588  score 29.00  100 game average 66.62
# episode  589  score 48.00  100 game average 65.86
# episode  590  score 27.00  100 game average 65.85
# episode  591  score 30.00  100 game average 65.30
# episode  592  score 81.00  100 game average 65.56
# episode  593  score 40.00  100 game average 64.49
# episode  594  score 30.00  100 game average 64.51
# episode  595  score 56.00  100 game average 64.93
# episode  596  score 78.00  100 game average 65.59
# episode  597  score 85.00  100 game average 65.95
# episode  598  score 286.00  100 game average 68.17
# episode  599  score 40.00  100 game average 68.11
# episode  600  score 125.00  100 game average 68.53
# episode  601  score 108.00  100 game average 68.65
# episode  602  score 58.00  100 game average 69.08
# episode  603  score 19.00  100 game average 67.95
# episode  604  score 145.00  100 game average 68.96
# episode  605  score 46.00  100 game average 69.11
# episode  606  score 68.00  100 game average 66.08
# episode  607  score 26.00  100 game average 65.74
# episode  608  score 44.00  100 game average 65.61
# episode  609  score 71.00  100 game average 65.13
# episode  610  score 25.00  100 game average 64.31
# episode  611  score 65.00  100 game average 64.65
# episode  612  score 19.00  100 game average 63.73
# episode  613  score 189.00  100 game average 65.24
# episode  614  score 14.00  100 game average 64.21
# episode  615  score 58.00  100 game average 64.63
# episode  616  score 29.00  100 game average 64.34
# episode  617  score 119.00  100 game average 64.92
# episode  618  score 32.00  100 game average 64.77
# episode  619  score 48.00  100 game average 64.20
# episode  620  score 37.00  100 game average 64.41
# episode  621  score 33.00  100 game average 63.78
# episode  622  score 41.00  100 game average 63.94
# episode  623  score 39.00  100 game average 63.89
# episode  624  score 21.00  100 game average 63.38
# episode  625  score 101.00  100 game average 63.95
# episode  626  score 11.00  100 game average 63.63
# episode  627  score 32.00  100 game average 62.83
# episode  628  score 96.00  100 game average 63.21
# episode  629  score 65.00  100 game average 63.43
# episode  630  score 13.00  100 game average 62.49
# episode  631  score 19.00  100 game average 62.24
# episode  632  score 14.00  100 game average 61.27
# episode  633  score 76.00  100 game average 61.44
# episode  634  score 15.00  100 game average 60.58
# episode  635  score 47.00  100 game average 60.54
# episode  636  score 23.00  100 game average 60.29
# episode  637  score 90.00  100 game average 60.50
# episode  638  score 20.00  100 game average 60.03
# episode  639  score 50.00  100 game average 59.39
# episode  640  score 38.00  100 game average 58.71
# episode  641  score 29.00  100 game average 58.78
# episode  642  score 92.00  100 game average 58.60
# episode  643  score 57.00  100 game average 58.75
# episode  644  score 67.00  100 game average 58.99
# episode  645  score 39.00  100 game average 58.27
# episode  646  score 64.00  100 game average 58.65
# episode  647  score 45.00  100 game average 58.52
# episode  648  score 52.00  100 game average 58.76
# episode  649  score 76.00  100 game average 58.58
# episode  650  score 100.00  100 game average 59.11
# episode  651  score 94.00  100 game average 59.68
# episode  652  score 58.00  100 game average 59.64
# episode  653  score 92.00  100 game average 59.71
# episode  654  score 115.00  100 game average 59.88
# episode  655  score 50.00  100 game average 58.26
# episode  656  score 25.00  100 game average 57.85
# episode  657  score 93.00  100 game average 58.44
# episode  658  score 18.00  100 game average 58.37
# episode  659  score 32.00  100 game average 58.23
# episode  660  score 20.00  100 game average 58.17
# episode  661  score 32.00  100 game average 58.19
# episode  662  score 116.00  100 game average 58.80
# episode  663  score 106.00  100 game average 59.68
# episode  664  score 21.00  100 game average 59.51
# episode  665  score 13.00  100 game average 59.35
# episode  666  score 40.00  100 game average 58.41
# episode  667  score 133.00  100 game average 59.50
# episode  668  score 19.00  100 game average 59.47
# episode  669  score 120.00  100 game average 59.68
# episode  670  score 127.00  100 game average 60.55
# episode  671  score 26.00  100 game average 60.31
# episode  672  score 18.00  100 game average 60.35
# episode  673  score 69.00  100 game average 60.81
# episode  674  score 28.00  100 game average 60.09
# episode  675  score 105.00  100 game average 60.49
# episode  676  score 15.00  100 game average 60.02
# episode  677  score 87.00  100 game average 59.71
# episode  678  score 93.00  100 game average 60.10
# episode  679  score 98.00  100 game average 60.60
# episode  680  score 51.00  100 game average 59.74
# episode  681  score 86.00  100 game average 60.43
# episode  682  score 41.00  100 game average 60.30
# episode  683  score 26.00  100 game average 60.36
# episode  684  score 31.00  100 game average 60.26
# episode  685  score 125.00  100 game average 60.86
# episode  686  score 59.00  100 game average 60.43
# episode  687  score 24.00  100 game average 59.46
# episode  688  score 38.00  100 game average 59.55
# episode  689  score 57.00  100 game average 59.64
# episode  690  score 71.00  100 game average 60.08
# episode  691  score 35.00  100 game average 60.13
# episode  692  score 44.00  100 game average 59.76
# episode  693  score 15.00  100 game average 59.51
# episode  694  score 39.00  100 game average 59.60
# episode  695  score 102.00  100 game average 60.06
# episode  696  score 106.00  100 game average 60.34
# episode  697  score 62.00  100 game average 60.11
# episode  698  score 35.00  100 game average 57.60
# episode  699  score 15.00  100 game average 57.35
# episode  700  score 160.00  100 game average 57.70
# episode  701  score 35.00  100 game average 56.97
# episode  702  score 31.00  100 game average 56.70
# episode  703  score 35.00  100 game average 56.86
# episode  704  score 108.00  100 game average 56.49
# episode  705  score 40.00  100 game average 56.43
# episode  706  score 42.00  100 game average 56.17
# episode  707  score 59.00  100 game average 56.50
# episode  708  score 26.00  100 game average 56.32
# episode  709  score 18.00  100 game average 55.79
# episode  710  score 48.00  100 game average 56.02
# episode  711  score 41.00  100 game average 55.78
# episode  712  score 52.00  100 game average 56.11
# episode  713  score 144.00  100 game average 55.66
# episode  714  score 27.00  100 game average 55.79
# episode  715  score 20.00  100 game average 55.41
# episode  716  score 63.00  100 game average 55.75
# episode  717  score 26.00  100 game average 54.82
# episode  718  score 69.00  100 game average 55.19
# episode  719  score 79.00  100 game average 55.50
# episode  720  score 191.00  100 game average 57.04
# episode  721  score 130.00  100 game average 58.01
# episode  722  score 22.00  100 game average 57.82
# episode  723  score 62.00  100 game average 58.05
# episode  724  score 17.00  100 game average 58.01
# episode  725  score 22.00  100 game average 57.22
# episode  726  score 28.00  100 game average 57.39
# episode  727  score 15.00  100 game average 57.22
# episode  728  score 95.00  100 game average 57.21
# episode  729  score 106.00  100 game average 57.62
# episode  730  score 29.00  100 game average 57.78
# episode  731  score 94.00  100 game average 58.53
# episode  732  score 33.00  100 game average 58.72
# episode  733  score 18.00  100 game average 58.14
# episode  734  score 23.00  100 game average 58.22
# episode  735  score 39.00  100 game average 58.14
# episode  736  score 66.00  100 game average 58.57
# episode  737  score 23.00  100 game average 57.90
# episode  738  score 25.00  100 game average 57.95
# episode  739  score 18.00  100 game average 57.63
# episode  740  score 42.00  100 game average 57.67
# episode  741  score 21.00  100 game average 57.59
# episode  742  score 111.00  100 game average 57.78
# episode  743  score 127.00  100 game average 58.48
# episode  744  score 113.00  100 game average 58.94
# episode  745  score 86.00  100 game average 59.41
# episode  746  score 21.00  100 game average 58.98
# episode  747  score 48.00  100 game average 59.01
# episode  748  score 23.00  100 game average 58.72
# episode  749  score 29.00  100 game average 58.25
# episode  750  score 30.00  100 game average 57.55
# episode  751  score 11.00  100 game average 56.72
# episode  752  score 66.00  100 game average 56.80
# episode  753  score 119.00  100 game average 57.07
# episode  754  score 155.00  100 game average 57.47
# episode  755  score 24.00  100 game average 57.21
# episode  756  score 57.00  100 game average 57.53
# episode  757  score 69.00  100 game average 57.29
# episode  758  score 30.00  100 game average 57.41
# episode  759  score 29.00  100 game average 57.38
# episode  760  score 31.00  100 game average 57.49
# episode  761  score 63.00  100 game average 57.80
# episode  762  score 45.00  100 game average 57.09
# episode  763  score 67.00  100 game average 56.70
# episode  764  score 18.00  100 game average 56.67
# episode  765  score 36.00  100 game average 56.90
# episode  766  score 17.00  100 game average 56.67
# episode  767  score 95.00  100 game average 56.29
# episode  768  score 86.00  100 game average 56.96
# episode  769  score 75.00  100 game average 56.51
# episode  770  score 35.00  100 game average 55.59
# episode  771  score 16.00  100 game average 55.49
# episode  772  score 10.00  100 game average 55.41
# episode  773  score 81.00  100 game average 55.53
# episode  774  score 19.00  100 game average 55.44
# episode  775  score 94.00  100 game average 55.33
# episode  776  score 130.00  100 game average 56.48
# episode  777  score 10.00  100 game average 55.71
# episode  778  score 166.00  100 game average 56.44
# episode  779  score 55.00  100 game average 56.01
# episode  780  score 33.00  100 game average 55.83
# episode  781  score 57.00  100 game average 55.54
# episode  782  score 15.00  100 game average 55.28
# episode  783  score 62.00  100 game average 55.64
# episode  784  score 13.00  100 game average 55.46
# episode  785  score 29.00  100 game average 54.50
# episode  786  score 19.00  100 game average 54.10
# episode  787  score 47.00  100 game average 54.33
# episode  788  score 108.00  100 game average 55.03
# episode  789  score 119.00  100 game average 55.65
# episode  790  score 21.00  100 game average 55.15
# episode  791  score 23.00  100 game average 55.03
# episode  792  score 54.00  100 game average 55.13
# episode  793  score 50.00  100 game average 55.48
# episode  794  score 31.00  100 game average 55.40
# episode  795  score 81.00  100 game average 55.19
# episode  796  score 145.00  100 game average 55.58
# episode  797  score 96.00  100 game average 55.92
# episode  798  score 51.00  100 game average 56.08
# episode  799  score 56.00  100 game average 56.49
# episode  800  score 18.00  100 game average 55.07
# episode  801  score 65.00  100 game average 55.37
# episode  802  score 13.00  100 game average 55.19
# episode  803  score 30.00  100 game average 55.14
# episode  804  score 24.00  100 game average 54.30
# episode  805  score 13.00  100 game average 54.03
# episode  806  score 31.00  100 game average 53.92
# episode  807  score 45.00  100 game average 53.78
# episode  808  score 28.00  100 game average 53.80
# episode  809  score 29.00  100 game average 53.91
# episode  810  score 30.00  100 game average 53.73
# episode  811  score 57.00  100 game average 53.89
# episode  812  score 90.00  100 game average 54.27
# episode  813  score 96.00  100 game average 53.79
# episode  814  score 63.00  100 game average 54.15
# episode  815  score 53.00  100 game average 54.48
# episode  816  score 45.00  100 game average 54.30
# episode  817  score 36.00  100 game average 54.40
# episode  818  score 20.00  100 game average 53.91
# episode  819  score 30.00  100 game average 53.42
# episode  820  score 67.00  100 game average 52.18
# episode  821  score 49.00  100 game average 51.37
# episode  822  score 15.00  100 game average 51.30
# episode  823  score 23.00  100 game average 50.91
# episode  824  score 18.00  100 game average 50.92
# episode  825  score 20.00  100 game average 50.90
# episode  826  score 22.00  100 game average 50.84
# episode  827  score 25.00  100 game average 50.94
# episode  828  score 24.00  100 game average 50.23
# episode  829  score 133.00  100 game average 50.50
# episode  830  score 90.00  100 game average 51.11
# episode  831  score 16.00  100 game average 50.33
# episode  832  score 44.00  100 game average 50.44
# episode  833  score 62.00  100 game average 50.88
# episode  834  score 27.00  100 game average 50.92
# episode  835  score 17.00  100 game average 50.70
# episode  836  score 77.00  100 game average 50.81
# episode  837  score 55.00  100 game average 51.13
# episode  838  score 22.00  100 game average 51.10
# episode  839  score 29.00  100 game average 51.21
# episode  840  score 26.00  100 game average 51.05
# episode  841  score 19.00  100 game average 51.03
# episode  842  score 55.00  100 game average 50.47
# episode  843  score 65.00  100 game average 49.85
# episode  844  score 36.00  100 game average 49.08
# episode  845  score 39.00  100 game average 48.61
# episode  846  score 41.00  100 game average 48.81
# episode  847  score 120.00  100 game average 49.53
# episode  848  score 33.00  100 game average 49.63
# episode  849  score 52.00  100 game average 49.86
# episode  850  score 20.00  100 game average 49.76
# episode  851  score 17.00  100 game average 49.82
# episode  852  score 19.00  100 game average 49.35
# episode  853  score 63.00  100 game average 48.79
# episode  854  score 62.00  100 game average 47.86
# episode  855  score 19.00  100 game average 47.81
# episode  856  score 33.00  100 game average 47.57
# episode  857  score 19.00  100 game average 47.07
# episode  858  score 13.00  100 game average 46.90
# episode  859  score 29.00  100 game average 46.90
# episode  860  score 123.00  100 game average 47.82
# episode  861  score 21.00  100 game average 47.40
# episode  862  score 10.00  100 game average 47.05
# episode  863  score 52.00  100 game average 46.90
# episode  864  score 52.00  100 game average 47.24
# episode  865  score 21.00  100 game average 47.09
# episode  866  score 13.00  100 game average 47.05
# episode  867  score 23.00  100 game average 46.33
# episode  868  score 17.00  100 game average 45.64
# episode  869  score 45.00  100 game average 45.34
# episode  870  score 14.00  100 game average 45.13
# episode  871  score 27.00  100 game average 45.24
# episode  872  score 89.00  100 game average 46.03
# episode  873  score 14.00  100 game average 45.36
# episode  874  score 64.00  100 game average 45.81
# episode  875  score 47.00  100 game average 45.34
# episode  876  score 63.00  100 game average 44.67
# episode  877  score 44.00  100 game average 45.01
# episode  878  score 55.00  100 game average 43.90
# episode  879  score 31.00  100 game average 43.66
# episode  880  score 95.00  100 game average 44.28
# episode  881  score 77.00  100 game average 44.48
# episode  882  score 45.00  100 game average 44.78
# episode  883  score 18.00  100 game average 44.34
# episode  884  score 74.00  100 game average 44.95
# episode  885  score 53.00  100 game average 45.19
# episode  886  score 70.00  100 game average 45.70
# episode  887  score 71.00  100 game average 45.94
# episode  888  score 23.00  100 game average 45.09
# episode  889  score 11.00  100 game average 44.01
# episode  890  score 52.00  100 game average 44.32
# episode  891  score 18.00  100 game average 44.27
# episode  892  score 37.00  100 game average 44.10
# episode  893  score 12.00  100 game average 43.72
# episode  894  score 23.00  100 game average 43.64
# episode  895  score 39.00  100 game average 43.22
# episode  896  score 20.00  100 game average 41.97
# episode  897  score 49.00  100 game average 41.50
# episode  898  score 45.00  100 game average 41.44
# episode  899  score 14.00  100 game average 41.02
# episode  900  score 138.00  100 game average 42.22
# episode  901  score 19.00  100 game average 41.76
# episode  902  score 44.00  100 game average 42.07
# episode  903  score 19.00  100 game average 41.96
# episode  904  score 50.00  100 game average 42.22
# episode  905  score 37.00  100 game average 42.46
# episode  906  score 16.00  100 game average 42.31
# episode  907  score 39.00  100 game average 42.25
# episode  908  score 42.00  100 game average 42.39
# episode  909  score 20.00  100 game average 42.30
# episode  910  score 20.00  100 game average 42.20
# episode  911  score 77.00  100 game average 42.40
# episode  912  score 39.00  100 game average 41.89
# episode  913  score 35.00  100 game average 41.28
# episode  914  score 34.00  100 game average 40.99
# episode  915  score 21.00  100 game average 40.67
# episode  916  score 24.00  100 game average 40.46
# episode  917  score 72.00  100 game average 40.82
# episode  918  score 49.00  100 game average 41.11
# episode  919  score 83.00  100 game average 41.64
# episode  920  score 32.00  100 game average 41.29
# episode  921  score 10.00  100 game average 40.90
# episode  922  score 45.00  100 game average 41.20
# episode  923  score 17.00  100 game average 41.14
# episode  924  score 19.00  100 game average 41.15
# episode  925  score 18.00  100 game average 41.13
# episode  926  score 127.00  100 game average 42.18
# episode  927  score 28.00  100 game average 42.21
# episode  928  score 14.00  100 game average 42.11
# episode  929  score 26.00  100 game average 41.04
# episode  930  score 18.00  100 game average 40.32
# episode  931  score 28.00  100 game average 40.44
# episode  932  score 11.00  100 game average 40.11
# episode  933  score 20.00  100 game average 39.69
# episode  934  score 45.00  100 game average 39.87
# episode  935  score 37.00  100 game average 40.07
# episode  936  score 38.00  100 game average 39.68
# episode  937  score 22.00  100 game average 39.35
# episode  938  score 15.00  100 game average 39.28
# episode  939  score 15.00  100 game average 39.14
# episode  940  score 41.00  100 game average 39.29
# episode  941  score 19.00  100 game average 39.29
# episode  942  score 35.00  100 game average 39.09
# episode  943  score 100.00  100 game average 39.44
# episode  944  score 31.00  100 game average 39.39
# episode  945  score 26.00  100 game average 39.26
# episode  946  score 10.00  100 game average 38.95
# episode  947  score 54.00  100 game average 38.29
# ...
# episode  3687  score 15.00  100 game average 22.82
# episode  3688  score 21.00  100 game average 22.76
# episode  3689  score 33.00  100 game average 22.70
# episode  3690  score 44.00  100 game average 22.86
# episode  3691  score 18.00  100 game average 22.85
# episode  3692  score 28.00  100 game average 23.04
# episode  3693  score 12.00  100 game average 23.01
# episode  3694  score 37.00  100 game average 23.25
# episode  3695  score 27.00  100 game average 23.39
# episode  3696  score 39.00  100 game average 23.54
# episode  3697  score 25.00  100 game average 23.62
# episode  3698  score 19.00  100 game average 23.55
# episode  3699  score 28.00  100 game average 23.72
# episode  3700  score 19.00  100 game average 23.66
# episode  3701  score 32.00  100 game average 23.61
# episode  3702  score 41.00  100 game average 23.90
# episode  3703  score 13.00  100 game average 23.73
# episode  3704  score 23.00  100 game average 23.85
# episode  3705  score 16.00  100 game average 23.78
# episode  3706  score 11.00  100 game average 23.68
# episode  3707  score 29.00  100 game average 23.57
# episode  3708  score 18.00  100 game average 23.56
# episode  3709  score 15.00  100 game average 23.54
# episode  3710  score 10.00  100 game average 23.11
# episode  3711  score 19.00  100 game average 23.06
# episode  3712  score 68.00  100 game average 23.60
# episode  3713  score 26.00  100 game average 23.76
# episode  3714  score 25.00  100 game average 23.67
# episode  3715  score 14.00  100 game average 23.72
# episode  3716  score 18.00  100 game average 23.76
# episode  3717  score 17.00  100 game average 23.54
# episode  3718  score 26.00  100 game average 23.55
# episode  3719  score 23.00  100 game average 23.67
# episode  3720  score 38.00  100 game average 23.71
# episode  3721  score 22.00  100 game average 23.81
# episode  3722  score 26.00  100 game average 23.69
# episode  3723  score 22.00  100 game average 23.69
# episode  3724  score 13.00  100 game average 23.59
# episode  3725  score 29.00  100 game average 23.64
# episode  3726  score 23.00  100 game average 23.72
# episode  3727  score 12.00  100 game average 23.63
# episode  3728  score 25.00  100 game average 23.59
# episode  3729  score 25.00  100 game average 23.70
# episode  3730  score 22.00  100 game average 23.82
# episode  3731  score 34.00  100 game average 23.95
# episode  3732  score 17.00  100 game average 23.92
# episode  3733  score 23.00  100 game average 23.98
# episode  3734  score 18.00  100 game average 24.05
# episode  3735  score 23.00  100 game average 24.02
# episode  3736  score 23.00  100 game average 23.73
# episode  3737  score 17.00  100 game average 23.79
# episode  3738  score 39.00  100 game average 24.02
# episode  3739  score 14.00  100 game average 23.85
# episode  3740  score 30.00  100 game average 23.89
# episode  3741  score 11.00  100 game average 23.84
# episode  3742  score 12.00  100 game average 23.71
# episode  3743  score 31.00  100 game average 23.77
# episode  3744  score 13.00  100 game average 23.67
# episode  3745  score 37.00  100 game average 23.85
# episode  3746  score 16.00  100 game average 23.80
# episode  3747  score 32.00  100 game average 23.72
# episode  3748  score 23.00  100 game average 23.60
# episode  3749  score 18.00  100 game average 23.55
# episode  3750  score 26.00  100 game average 23.37
# episode  3751  score 13.00  100 game average 23.31
# episode  3752  score 35.00  100 game average 23.43
# episode  3753  score 33.00  100 game average 23.44
# episode  3754  score 16.00  100 game average 23.34
# episode  3755  score 38.00  100 game average 23.56
# episode  3756  score 19.00  100 game average 23.63
# episode  3757  score 57.00  100 game average 24.01
# episode  3758  score 31.00  100 game average 24.18
# episode  3759  score 53.00  100 game average 24.44
# episode  3760  score 35.00  100 game average 24.65
# episode  3761  score 14.00  100 game average 24.67
# episode  3762  score 14.00  100 game average 24.09
# episode  3763  score 29.00  100 game average 24.11
# episode  3764  score 14.00  100 game average 24.07
# episode  3765  score 24.00  100 game average 24.14
# episode  3766  score 30.00  100 game average 24.08
# episode  3767  score 16.00  100 game average 24.06
# episode  3768  score 11.00  100 game average 23.90
# episode  3769  score 16.00  100 game average 23.90
# episode  3770  score 30.00  100 game average 23.97
# episode  3771  score 18.00  100 game average 23.80
# episode  3772  score 19.00  100 game average 23.75
# episode  3773  score 50.00  100 game average 23.87
# episode  3774  score 14.00  100 game average 23.85
# episode  3775  score 26.00  100 game average 23.51
# episode  3776  score 19.00  100 game average 23.50
# episode  3777  score 56.00  100 game average 23.77
# episode  3778  score 38.00  100 game average 24.01
# episode  3779  score 96.00  100 game average 24.83
# episode  3780  score 14.00  100 game average 24.79
# episode  3781  score 12.00  100 game average 24.78
# episode  3782  score 16.00  100 game average 24.84
# episode  3783  score 11.00  100 game average 24.85
# episode  3784  score 20.00  100 game average 24.89
# episode  3785  score 16.00  100 game average 24.93
# episode  3786  score 11.00  100 game average 24.87
# episode  3787  score 19.00  100 game average 24.91
# episode  3788  score 35.00  100 game average 25.05
# episode  3789  score 42.00  100 game average 25.14
# episode  3790  score 32.00  100 game average 25.02
# episode  3791  score 46.00  100 game average 25.30
# episode  3792  score 22.00  100 game average 25.24
# episode  3793  score 43.00  100 game average 25.55
# episode  3794  score 10.00  100 game average 25.28
# episode  3795  score 17.00  100 game average 25.18
# episode  3796  score 10.00  100 game average 24.89
# episode  3797  score 11.00  100 game average 24.75
# episode  3798  score 11.00  100 game average 24.67
# episode  3799  score 12.00  100 game average 24.51
# episode  3800  score 21.00  100 game average 24.53
# episode  3801  score 20.00  100 game average 24.41
# episode  3802  score 19.00  100 game average 24.19
# episode  3803  score 10.00  100 game average 24.16
# episode  3804  score 14.00  100 game average 24.07
# episode  3805  score 13.00  100 game average 24.04
# episode  3806  score 24.00  100 game average 24.17
# episode  3807  score 16.00  100 game average 24.04
# episode  3808  score 24.00  100 game average 24.10
# episode  3809  score 43.00  100 game average 24.38
# episode  3810  score 33.00  100 game average 24.61
# episode  3811  score 36.00  100 game average 24.78
# episode  3812  score 18.00  100 game average 24.28
# episode  3813  score 13.00  100 game average 24.15
# episode  3814  score 16.00  100 game average 24.06
# episode  3815  score 15.00  100 game average 24.07
# episode  3816  score 17.00  100 game average 24.06
# episode  3817  score 11.00  100 game average 24.00
# episode  3818  score 16.00  100 game average 23.90
# episode  3819  score 15.00  100 game average 23.82
# episode  3820  score 20.00  100 game average 23.64
# episode  3821  score 75.00  100 game average 24.17
# episode  3822  score 27.00  100 game average 24.18
# episode  3823  score 16.00  100 game average 24.12
# episode  3824  score 16.00  100 game average 24.15
# episode  3825  score 12.00  100 game average 23.98
# episode  3826  score 37.00  100 game average 24.12
# episode  3827  score 50.00  100 game average 24.50
# episode  3828  score 49.00  100 game average 24.74
# episode  3829  score 18.00  100 game average 24.67
# episode  3830  score 58.00  100 game average 25.03
# episode  3831  score 20.00  100 game average 24.89
# episode  3832  score 12.00  100 game average 24.84
# episode  3833  score 18.00  100 game average 24.79
# episode  3834  score 20.00  100 game average 24.81
# episode  3835  score 13.00  100 game average 24.71
# episode  3836  score 15.00  100 game average 24.63
# episode  3837  score 35.00  100 game average 24.81
# episode  3838  score 18.00  100 game average 24.60
# episode  3839  score 19.00  100 game average 24.65
# episode  3840  score 14.00  100 game average 24.49
# episode  3841  score 17.00  100 game average 24.55
# episode  3842  score 20.00  100 game average 24.63
# episode  3843  score 19.00  100 game average 24.51
# episode  3844  score 22.00  100 game average 24.60
# episode  3845  score 48.00  100 game average 24.71
# episode  3846  score 32.00  100 game average 24.87
# episode  3847  score 14.00  100 game average 24.69
# episode  3848  score 14.00  100 game average 24.60
# episode  3849  score 33.00  100 game average 24.75
# episode  3850  score 20.00  100 game average 24.69
# episode  3851  score 25.00  100 game average 24.81
# episode  3852  score 22.00  100 game average 24.68
# episode  3853  score 22.00  100 game average 24.57
# episode  3854  score 12.00  100 game average 24.53
# episode  3855  score 42.00  100 game average 24.57
# episode  3856  score 40.00  100 game average 24.78
# episode  3857  score 11.00  100 game average 24.32
# episode  3858  score 10.00  100 game average 24.11
# episode  3859  score 18.00  100 game average 23.76
# episode  3860  score 23.00  100 game average 23.64
# episode  3861  score 13.00  100 game average 23.63
# episode  3862  score 27.00  100 game average 23.76
# episode  3863  score 20.00  100 game average 23.67
# episode  3864  score 13.00  100 game average 23.66
# episode  3865  score 14.00  100 game average 23.56
# episode  3866  score 25.00  100 game average 23.51
# episode  3867  score 24.00  100 game average 23.59
# episode  3868  score 53.00  100 game average 24.01
# episode  3869  score 28.00  100 game average 24.13
# episode  3870  score 31.00  100 game average 24.14
# episode  3871  score 44.00  100 game average 24.40
# episode  3872  score 16.00  100 game average 24.37
# episode  3873  score 19.00  100 game average 24.06
# episode  3874  score 16.00  100 game average 24.08
# episode  3875  score 10.00  100 game average 23.92
# episode  3876  score 18.00  100 game average 23.91
# episode  3877  score 37.00  100 game average 23.72
# episode  3878  score 14.00  100 game average 23.48
# episode  3879  score 15.00  100 game average 22.67
# episode  3880  score 22.00  100 game average 22.75
# episode  3881  score 42.00  100 game average 23.05
# episode  3882  score 14.00  100 game average 23.03
# episode  3883  score 14.00  100 game average 23.06
# episode  3884  score 20.00  100 game average 23.06
# episode  3885  score 12.00  100 game average 23.02
# episode  3886  score 17.00  100 game average 23.08
# episode  3887  score 19.00  100 game average 23.08
# episode  3888  score 14.00  100 game average 22.87
# episode  3889  score 15.00  100 game average 22.60
# episode  3890  score 10.00  100 game average 22.38
# episode  3891  score 71.00  100 game average 22.63
# episode  3892  score 31.00  100 game average 22.72
# episode  3893  score 14.00  100 game average 22.43
# episode  3894  score 25.00  100 game average 22.58
# episode  3895  score 14.00  100 game average 22.55
# episode  3896  score 22.00  100 game average 22.67
# episode  3897  score 23.00  100 game average 22.79
# episode  3898  score 15.00  100 game average 22.83
# episode  3899  score 22.00  100 game average 22.93
# episode  3900  score 20.00  100 game average 22.92
# episode  3901  score 17.00  100 game average 22.89
# episode  3902  score 41.00  100 game average 23.11
# episode  3903  score 39.00  100 game average 23.40
# episode  3904  score 28.00  100 game average 23.54
# episode  3905  score 17.00  100 game average 23.58
# episode  3906  score 10.00  100 game average 23.44
# episode  3907  score 18.00  100 game average 23.46
# episode  3908  score 20.00  100 game average 23.42
# episode  3909  score 29.00  100 game average 23.28
# episode  3910  score 14.00  100 game average 23.09
# episode  3911  score 18.00  100 game average 22.91
# episode  3912  score 15.00  100 game average 22.88
# episode  3913  score 13.00  100 game average 22.88
# episode  3914  score 20.00  100 game average 22.92
# episode  3915  score 17.00  100 game average 22.94
# episode  3916  score 48.00  100 game average 23.25
# episode  3917  score 12.00  100 game average 23.26
# episode  3918  score 15.00  100 game average 23.25
# episode  3919  score 15.00  100 game average 23.25
# episode  3920  score 23.00  100 game average 23.28
# episode  3921  score 19.00  100 game average 22.72
# episode  3922  score 30.00  100 game average 22.75
# episode  3923  score 35.00  100 game average 22.94
# episode  3924  score 14.00  100 game average 22.92
# episode  3925  score 14.00  100 game average 22.94
# episode  3926  score 23.00  100 game average 22.80
# episode  3927  score 16.00  100 game average 22.46
# episode  3928  score 26.00  100 game average 22.23
# episode  3929  score 40.00  100 game average 22.45
# episode  3930  score 10.00  100 game average 21.97
# episode  3931  score 21.00  100 game average 21.98
# episode  3932  score 12.00  100 game average 21.98
# episode  3933  score 22.00  100 game average 22.02
# episode  3934  score 25.00  100 game average 22.07
# episode  3935  score 29.00  100 game average 22.23
# episode  3936  score 21.00  100 game average 22.29
# episode  3937  score 21.00  100 game average 22.15
# episode  3938  score 18.00  100 game average 22.15
# episode  3939  score 15.00  100 game average 22.11
# episode  3940  score 33.00  100 game average 22.30
# episode  3941  score 49.00  100 game average 22.62
# episode  3942  score 32.00  100 game average 22.74
# episode  3943  score 19.00  100 game average 22.74
# episode  3944  score 35.00  100 game average 22.87
# episode  3945  score 44.00  100 game average 22.83
# episode  3946  score 24.00  100 game average 22.75
# episode  3947  score 20.00  100 game average 22.81
# episode  3948  score 19.00  100 game average 22.86
# episode  3949  score 35.00  100 game average 22.88
# episode  3950  score 18.00  100 game average 22.86
# episode  3951  score 65.00  100 game average 23.26
# episode  3952  score 20.00  100 game average 23.24
# episode  3953  score 10.00  100 game average 23.12
# episode  3954  score 21.00  100 game average 23.21
# episode  3955  score 11.00  100 game average 22.90
# episode  3956  score 29.00  100 game average 22.79
# episode  3957  score 18.00  100 game average 22.86
# episode  3958  score 14.00  100 game average 22.90
# episode  3959  score 22.00  100 game average 22.94
# episode  3960  score 20.00  100 game average 22.91
# episode  3961  score 27.00  100 game average 23.05
# episode  3962  score 18.00  100 game average 22.96
# episode  3963  score 21.00  100 game average 22.97
# episode  3964  score 20.00  100 game average 23.04
# episode  3965  score 18.00  100 game average 23.08
# episode  3966  score 37.00  100 game average 23.20
# episode  3967  score 19.00  100 game average 23.15
# episode  3968  score 24.00  100 game average 22.86
# episode  3969  score 30.00  100 game average 22.88
# episode  3970  score 20.00  100 game average 22.77
# episode  3971  score 10.00  100 game average 22.43
# episode  3972  score 43.00  100 game average 22.70
# episode  3973  score 13.00  100 game average 22.64
# episode  3974  score 27.00  100 game average 22.75
# episode  3975  score 29.00  100 game average 22.94
# episode  3976  score 20.00  100 game average 22.96
# episode  3977  score 23.00  100 game average 22.82
# episode  3978  score 30.00  100 game average 22.98
# episode  3979  score 26.00  100 game average 23.09
# episode  3980  score 39.00  100 game average 23.26
# episode  3981  score 27.00  100 game average 23.11
# episode  3982  score 56.00  100 game average 23.53
# episode  3983  score 17.00  100 game average 23.56
# episode  3984  score 12.00  100 game average 23.48
# episode  3985  score 22.00  100 game average 23.58
# episode  3986  score 33.00  100 game average 23.74
# episode  3987  score 9.00  100 game average 23.64
# episode  3988  score 12.00  100 game average 23.62
# episode  3989  score 13.00  100 game average 23.60
# episode  3990  score 12.00  100 game average 23.62
# episode  3991  score 28.00  100 game average 23.19
# episode  3992  score 39.00  100 game average 23.27
# episode  3993  score 10.00  100 game average 23.23
# episode  3994  score 17.00  100 game average 23.15
# episode  3995  score 18.00  100 game average 23.19
# episode  3996  score 13.00  100 game average 23.10
# episode  3997  score 24.00  100 game average 23.11
# episode  3998  score 19.00  100 game average 23.15
# episode  3999  score 31.00  100 game average 23.24
